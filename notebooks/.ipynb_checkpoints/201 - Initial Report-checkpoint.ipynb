# %% [markdown]
# # Initial Report

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier #Import scikit-Tree For Decision Tree
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import classification_report,confusion_matrix #import Confusion Matrix
from sklearn.model_selection import train_test_split # Splitting the data
from sklearn import preprocessing # Normalizing

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from IPython.display import Image, display, HTML
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import time
# Out:
# D:\Users\sourc\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
df = pd.read_csv("../data/external/accuracies.csv",index_col=0)

# %%
# format_dict = {'sum':'${0:,.0f}', 'date': '{:%m-%Y}', 'pct_of_total': '{:.2%}'}
# monthly_sales.style.format(format_dict).hide_index()

(df.style \
#  .format(format_dict)
    .background_gradient(subset=['Accuracy','Precision','Recall','F1','ROC'], cmap='BuGn') \
    .format("{:0.2%}") \
).render()
# Out:
# '<style  type="text/css" >\n    #T_f3d31964_6ac1_11ea_ba4a_40e2302f20c8row0_col0 {\n            background-color:  #ebf7fa;\n            color:  #000000;\n        }    #T_f3d31964_6ac1_11ea_ba4a_40e2302f20c8row0_col1 {\n            background-color:  #00692a;\n            color:  #f1f1f1;\n        }    #T_f3d31964_6ac1_11ea_ba4a_40e2302f20c8row0_col2 {\n            background-color:  #36a164;\n            color:  #000000;\n        }    #T_f3d31964_6ac1_11ea_ba4a_40e2302f20c8row0_col3 {\n            background-color:  #18823d;\n            color:  #f1f1f1;\n        }    #T_f3d31964_6ac1_11ea_ba4a_40e2302f20c8row0_col4 {\n            background-color:  #4ab381;\n            color:  #000000;\n        }    #T_f3d31964_6ac1_11ea_ba4a_40e2302f20c8row1_col0 {\n            background-color:  #e5f5f9;\n            color:  #000000;\n        }    #T_f3d31964_6ac1_11ea_ba4a_40e2302f20c8row1_col1 {\n            background-color:  #026f2e;\n            color:  #f1f1f1;\n        }    #T_f3d31964_6a
# ...

# %%
(df.style \
#  .format(format_dict)
#  .hide_index()
    .highlight_max(color='lightgreen') \
    .highlight_min(color='#cd4f39') \
    .format("{:0.2%}") \
).render()
# Out:
# '<style  type="text/css" >\n    #T_f3ddd96e_6ac1_11ea_a733_40e2302f20c8row4_col2 {\n            : ;\n            background-color:  #cd4f39;\n        }    #T_f3ddd96e_6ac1_11ea_a733_40e2302f20c8row4_col3 {\n            : ;\n            background-color:  #cd4f39;\n        }    #T_f3ddd96e_6ac1_11ea_a733_40e2302f20c8row4_col4 {\n            : ;\n            background-color:  #cd4f39;\n        }    #T_f3ddd96e_6ac1_11ea_a733_40e2302f20c8row5_col0 {\n            background-color:  lightgreen;\n            : ;\n        }    #T_f3ddd96e_6ac1_11ea_a733_40e2302f20c8row5_col1 {\n            background-color:  lightgreen;\n            : ;\n        }    #T_f3ddd96e_6ac1_11ea_a733_40e2302f20c8row5_col2 {\n            background-color:  lightgreen;\n            : ;\n        }    #T_f3ddd96e_6ac1_11ea_a733_40e2302f20c8row5_col3 {\n            background-color:  lightgreen;\n            : ;\n        }    #T_f3ddd96e_6ac1_11ea_a733_40e2302f20c8row5_col4 {\n            background-color:  lightgreen
# ...

# %%
(df.style \
#  .format(format_dict)
#  .hide_index()
    .bar(color='#ff0081', vmin=0, subset=['Accuracy'], align='zero') \
    .bar(color='#ff48a5', vmin=0, subset=['Precision'], align='zero') \
    .bar(color='#ff77bc', vmin=0, subset=['Recall'], align='zero') \
    .bar(color='#ffaed7', vmin=0, subset=['F1'], align='zero') \
    .bar(color='#ffcae5', vmin=0, subset=['ROC'], align='zero') \
    .set_caption('Accuracy Table') \
    .format("{:0.2%}") \
).render()
# Out:
# '<style  type="text/css" >\n    #T_f3f3c436_6ac1_11ea_9924_40e2302f20c8row0_col0 {\n            width:  10em;\n             height:  80%;\n            background:  linear-gradient(90deg, transparent 50.0%, #ff0081 50.0%, #ff0081 91.5%, transparent 91.5%);\n        }    #T_f3f3c436_6ac1_11ea_9924_40e2302f20c8row0_col1 {\n            width:  10em;\n             height:  80%;\n            background:  linear-gradient(90deg, transparent 50.0%, #ff48a5 50.0%, #ff48a5 97.0%, transparent 97.0%);\n        }    #T_f3f3c436_6ac1_11ea_9924_40e2302f20c8row0_col2 {\n            width:  10em;\n             height:  80%;\n            background:  linear-gradient(90deg, transparent 50.0%, #ff77bc 50.0%, #ff77bc 83.7%, transparent 83.7%);\n        }    #T_f3f3c436_6ac1_11ea_9924_40e2302f20c8row0_col3 {\n            width:  10em;\n             height:  80%;\n            background:  linear-gradient(90deg, transparent 50.0%, #ffaed7 50.0%, #ffaed7 89.8%, transparent 89.8%);\n        }    #T_f3f3c436_6a
# ...
