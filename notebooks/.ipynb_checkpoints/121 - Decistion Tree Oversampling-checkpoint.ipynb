# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier #Import scikit-Tree For Decision Tree
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import classification_report,confusion_matrix #import Confusion Matrix
from sklearn.model_selection import train_test_split # Splitting the data
from sklearn import preprocessing # Normalizing

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import time

# %%
df_o = pd.read_csv("../data/processed/data_oversampled.csv",index_col=0)

# %%
# Normalizing the data
x = df_o.values #returns a numpy array
col = df_o.columns
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_n = pd.DataFrame(x_scaled, columns = col)

# df_n

# %%
X = df_o.drop("isFirstDown",1)   #Feature Matrix
y = df_o["isFirstDown"]          #Target Variable

# %%
# from sklearn.model_selection import train_test_split # Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=72)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (31544, 19)
# (13520, 19)
# (31544,)
# (13520,)

# %%
# Create Decision Tree classifer object
dtree = DecisionTreeClassifier(criterion="entropy")

# %%
# Train Decision Tree Classifer
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#Predict the response for test dataset
y_pred = dtree.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred)
print('F1 score: %f' % f1)

acc = pd.read_csv("../data/external/accuracies.csv", index_col=0)
acc.at['Decision Tree, Oversampled', 'Accuracy'] = accuracy
acc.at['Decision Tree, Oversampled', 'Precision'] = precision
acc.at['Decision Tree, Oversampled', 'Recall'] = recall
acc.at['Decision Tree, Oversampled', 'F1'] = f1
acc.to_csv("../data/external/accuracies.csv")
# Out:
# Accuracy: 0.883432
# Precision: 0.833101
# Recall: 0.961758
# F1 score: 0.892818

# %%
#Present Confusion Matrix to show accuracy
print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87      6695
#            1       0.83      0.96      0.89      6825
#
#    micro avg       0.88      0.88      0.88     13520
#    macro avg       0.89      0.88      0.88     13520
# weighted avg       0.89      0.88      0.88     13520
#
#  [[5380 1315]
#  [ 261 6564]]

# %%
features = list(X)
#features

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True,rotate=True, max_depth=3)

import pydot
graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png(), width=7860, height=2160)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-a52273bc2c6f> in <module>
#       2 export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True,rotate=True, max_depth=3)
#       3
# ----> 4 import pydot
#       5 graph = pydot.graph_from_dot_data(dot_data.getvalue())
#       6 Image(graph[0].create_png(), width=7860, height=2160)
#
# ModuleNotFoundError: No module named 'pydot'

# %%
from sklearn.tree import _tree

def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [ \
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!" \
        for i in tree_.feature \
    ]
    print("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "  " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            print("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print("{}return {}".format(indent, tree_.value[node]))

    recurse(0, 1)
    
tree_to_code(dtree, features)
# Out:
# def tree(X, Y, S, A, Orientation, Dir, Season, Distance, HomeScoreBeforePlay, VisitorScoreBeforePlay, DefendersInTheBox, YardsToTouchdown, PlayerHeightInches, PlayerWeight, Age, Week, StadiumTypeCode, Cornerbacks, DefensiveEnds):
#   if Distance <= 5.5:
#     if Distance <= 2.5:
#       if A <= 1.8550000190734863:
#         if S <= 4.120000123977661:
#           if A <= 1.5149999856948853:
#             if Distance <= 1.5:
#               if Y <= 22.445000648498535:
#                 return [[9. 0.]]
#               else:  # if Y > 22.445000648498535
#                 if Season <= 2017.5:
#                   if HomeScoreBeforePlay <= 32.0:
#                     if VisitorScoreBeforePlay <= 27.5:
#                       if PlayerWeight <= 199.5:
#                         return [[ 0. 12.]]
#                       else:  # if PlayerWeight > 199.5
#                         if X <= 13.794999599456787:
#                           return [[0. 9.]]
#                         else:  # if X > 13.794999599456787
#                           if DefendersInTheBox <= 8.5:
#                             if PlayerWeight <= 211.0:
#                               return [[7. 0.]]
#                             else:  # if PlayerWeight > 211.0
#                               if Y <= 24.460000038146973:
#                                 if X <= 57.28499984741211:
#                                   if DefendersInTheBox <= 7.5:
#                                     return [[0. 5.]]
#                                   else:  # if DefendersInTheBox > 7.5
#                                     return [[3. 0.]]
#                                 else:  # if X > 57.28499984741211
#                                   return [[8. 0.]]
#                               else:  # if Y > 24.460000038146973
#                                 if Orientation <= 349.84999084472656:
#                                   if A <= 0.7700000107288361:
#                                     return [[ 0. 23.]]
#                                   else:  # if A > 0.7700000107288361
#                                     if A <= 1.0699999928474426:
#                                       return [[6. 0.]]
#                                     else:  # if A > 1.0699999928474426
#                                       if PlayerHeightInches <= 71.5:
#                                         if Y <= 29.390000343322754:
#                                           return [[3. 0.]]
#                                         else:  # if Y > 29.390000343322754
#                                           return [[0. 1.]]
#                                       else:  # if PlayerHeightInches > 71.5
#                                         if YardsToTouchdown <= 72.5:
#                                           return [[ 0. 26.]]
#                                         else:  # if YardsToTouchdown > 72.5
#                                           return [[1. 0.]]
#                                 else:  # if Orientation > 349.84999084472656
#                                   return [[4. 0.]]
#                           else:  # if DefendersInTheBox > 8.5
#                             if X <= 14.195000171661377:
#                               return [[0. 2.]]
#                             else:  # if X > 14.195000171661377
#                               return [[23.  0.]]
#                     else:  # if VisitorScoreBeforePlay > 27.5
#                       return [[7. 0.]]
#                   else:  # if HomeScoreBeforePlay > 32.0
#                     return [[ 0. 11.]]
#                 else:  # if Season > 2017.5
#                   if Orientation <= 87.92500305175781:
#                     if Age <= 24.5:
#                       if Dir <= 51.85499954223633:
#                         return [[1. 0.]]
#                       else:  # if Dir > 51.85499954223633
#                         return [[0. 4.]]
#                     else:  # if Age > 24.5
#                       return [[5. 0.]]
#                   else:  # if Orientation > 87.92500305175781
#                     if StadiumTypeCode <= 3.5:
#                       if VisitorScoreBeforePlay <= 16.5:
#                         return [[ 0. 40.]]
#                       else:  # if VisitorScoreBeforePlay > 16.5
#                         if PlayerWeight <= 221.0:
#                           return [[3. 0.]]
#                         else:  # if PlayerWeight > 221.0
#                           return [[ 0. 12.]]
#                     else:  # if StadiumTypeCode > 3.5
#                       if Orientation <= 105.59500122070312:
#                         return [[0. 3.]]
#                       else:  # if Orientation > 105.59500122070312
#                         return [[3. 0.]]
#             else:  # if Distance > 1.5
#               if Orientation <= 189.86499786376953:
#                 return [[22.  0.]]
#               else:  # if Orientation > 189.86499786376953
#                 if Orientation <= 269.3249969482422:
#                   if Dir <= 289.3350067138672:
#                     return [[0. 8.]]
#                   else:  # if Dir > 289.3350067138672
#                     if StadiumTypeCode <= 2.5:
#                       return [[5. 0.]]
#                     else:  # if StadiumTypeCode > 2.5
#                       return [[0. 2.]]
#                 else:  # if Orientation > 269.3249969482422
#                   return [[7. 0.]]
#           else:  # if A > 1.5149999856948853
#             if Y <= 29.949999809265137:
#               if A <= 1.8350000381469727:
#                 if Y <= 28.880000114440918:
#                   if Orientation <= 2.665000081062317:
#                     return [[3. 0.]]
#                   else:  # if Orientation > 2.665000081062317
#                     if PlayerWeight <= 210.5:
#                       if Week <= 11.5:
#                         if Cornerbacks <= 0.5:
#                           return [[2. 0.]]
#                         else:  # if Cornerbacks > 0.5
#                           if Age <= 24.5:
#                             return [[ 0. 12.]]
#                           else:  # if Age > 24.5
#                             if Orientation <= 106.09000396728516:
#                               return [[3. 0.]]
#                             else:  # if Orientation > 106.09000396728516
#                               if S <= 2.5350000858306885:
#                                 return [[1. 0.]]
#                               else:  # if S > 2.5350000858306885
#                                 return [[0. 6.]]
#                       else:  # if Week > 11.5
#                         return [[5. 0.]]
#                     else:  # if PlayerWeight > 210.5
#                       if Orientation <= 350.2850036621094:
#                         if PlayerHeightInches <= 74.5:
#                           if YardsToTouchdown <= 63.0:
#                             if Week <= 10.5:
#                               if X <= 101.54499816894531:
#                                 if Dir <= 244.06500244140625:
#                                   return [[ 0. 24.]]
#                                 else:  # if Dir > 244.06500244140625
#                                   if PlayerHeightInches <= 71.0:
#                                     return [[3. 0.]]
#                                   else:  # if PlayerHeightInches > 71.0
#                                     if X <= 15.079999923706055:
#                                       return [[ 0. 13.]]
#                                     else:  # if X > 15.079999923706055
#                                       if Cornerbacks <= 1.5:
#                                         return [[2. 0.]]
#                                       else:  # if Cornerbacks > 1.5
#                                         return [[0. 4.]]
#                               else:  # if X > 101.54499816894531
#                                 return [[3. 0.]]
#                             else:  # if Week > 10.5
#                               return [[ 0. 39.]]
#                           else:  # if YardsToTouchdown > 63.0
#                             if DefendersInTheBox <= 7.5:
#                               if PlayerWeight <= 232.5:
#                                 return [[5. 0.]]
#                               else:  # if PlayerWeight > 232.5
#                                 if A <= 1.7300000190734863:
#                                   return [[0. 1.]]
#                                 else:  # if A > 1.7300000190734863
#                                   return [[1. 0.]]
#                             else:  # if DefendersInTheBox > 7.5
#                               if Y <= 27.119999885559082:
#                                 return [[ 0. 16.]]
#                               else:  # if Y > 27.119999885559082
#                                 return [[1. 0.]]
#                         else:  # if PlayerHeightInches > 74.5
#                           if Y <= 25.609999656677246:
#                             return [[0. 1.]]
#                           else:  # if Y > 25.609999656677246
#                             return [[3. 0.]]
#                       else:  # if Orientation > 350.2850036621094
#                         return [[2. 0.]]
#                 else:  # if Y > 28.880000114440918
#                   if Orientation <= 277.6999969482422:
#                     if PlayerWeight <= 207.5:
#                       return [[0. 3.]]
#                     else:  # if PlayerWeight > 207.5
#                       if PlayerWeight <= 235.5:
#                         return [[12.  0.]]
#                       else:  # if PlayerWeight > 235.5
#                         if Dir <= 179.38000106811523:
#                           return [[0. 2.]]
#                         else:  # if Dir > 179.38000106811523
#                           return [[2. 0.]]
#                   else:  # if Orientation > 277.6999969482422
#                     return [[0. 6.]]
#               else:  # if A > 1.8350000381469727
#                 return [[4. 0.]]
#             else:  # if Y > 29.949999809265137
#               if Week <= 2.5:
#                 return [[2. 0.]]
#               else:  # if Week > 2.5
#                 if VisitorScoreBeforePlay <= 8.5:
#                   if HomeScoreBeforePlay <= 8.5:
#                     if Dir <= 285.1449890136719:
#                       if PlayerWeight <= 227.5:
#                         return [[ 0. 28.]]
#                       else:  # if PlayerWeight > 227.5
#                         return [[1. 0.]]
#                     else:  # if Dir > 285.1449890136719
#                       return [[2. 0.]]
#                   else:  # if HomeScoreBeforePlay > 8.5
#                     if DefendersInTheBox <= 8.5:
#                       return [[5. 0.]]
#                     else:  # if DefendersInTheBox > 8.5
#                       return [[0. 3.]]
#                 else:  # if VisitorScoreBeforePlay > 8.5
#                   return [[ 0. 40.]]
#         else:  # if S > 4.120000123977661
#           if Y <= 33.77499961853027:
#             if DefendersInTheBox <= 7.5:
#               if Orientation <= 47.47500038146973:
#                 if YardsToTouchdown <= 57.5:
#                   return [[5. 0.]]
#                 else:  # if YardsToTouchdown > 57.5
#                   return [[0. 4.]]
#               else:  # if Orientation > 47.47500038146973
#                 if Week <= 15.5:
#                   if StadiumTypeCode <= 2.5:
#                     if YardsToTouchdown <= 7.5:
#                       if Week <= 6.5:
#                         return [[2. 0.]]
#                       else:  # if Week > 6.5
#                         if DefensiveEnds <= 0.5:
#                           return [[1. 0.]]
#                         else:  # if DefensiveEnds > 0.5
#                           if Week <= 14.0:
#                             return [[ 0. 16.]]
#                           else:  # if Week > 14.0
#                             return [[1. 0.]]
#                     else:  # if YardsToTouchdown > 7.5
#                       if A <= 1.4450000524520874:
#                         if Age <= 21.5:
#                           if Y <= 21.300000190734863:
#                             return [[1. 0.]]
#                           else:  # if Y > 21.300000190734863
#                             return [[0. 8.]]
#                         else:  # if Age > 21.5
#                           return [[  0. 118.]]
#                       else:  # if A > 1.4450000524520874
#                         if VisitorScoreBeforePlay <= 20.5:
#                           if A <= 1.4550000429153442:
#                             return [[1. 0.]]
#                           else:  # if A > 1.4550000429153442
#                             if A <= 1.8450000286102295:
#                               if Y <= 27.97000026702881:
#                                 if Y <= 27.56999969482422:
#                                   if Orientation <= 190.81500244140625:
#                                     return [[ 0. 46.]]
#                                   else:  # if Orientation > 190.81500244140625
#                                     if A <= 1.5299999713897705:
#                                       return [[ 0. 11.]]
#                                     else:  # if A > 1.5299999713897705
#                                       if Dir <= 232.33499908447266:
#                                         if PlayerWeight <= 204.5:
#                                           return [[1. 0.]]
#                                         else:  # if PlayerWeight > 204.5
#                                           return [[0. 6.]]
#                                       else:  # if Dir > 232.33499908447266
#                                         return [[2. 0.]]
#                                 else:  # if Y > 27.56999969482422
#                                   return [[1. 0.]]
#                               else:  # if Y > 27.97000026702881
#                                 return [[ 0. 44.]]
#                             else:  # if A > 1.8450000286102295
#                               return [[1. 0.]]
#                         else:  # if VisitorScoreBeforePlay > 20.5
#                           return [[2. 0.]]
#                   else:  # if StadiumTypeCode > 2.5
#                     if S <= 4.819999933242798:
#                       return [[ 0. 20.]]
#                     else:  # if S > 4.819999933242798
#                       if StadiumTypeCode <= 3.5:
#                         return [[7. 0.]]
#                       else:  # if StadiumTypeCode > 3.5
#                         return [[0. 3.]]
#                 else:  # if Week > 15.5
#                   if VisitorScoreBeforePlay <= 5.0:
#                     if Dir <= 229.86000061035156:
#                       if DefensiveEnds <= 1.5:
#                         if Dir <= 145.2949981689453:
#                           return [[3. 0.]]
#                         else:  # if Dir > 145.2949981689453
#                           return [[0. 6.]]
#                       else:  # if DefensiveEnds > 1.5
#                         return [[ 0. 15.]]
#                     else:  # if Dir > 229.86000061035156
#                       return [[2. 0.]]
#                   else:  # if VisitorScoreBeforePlay > 5.0
#                     return [[3. 0.]]
#             else:  # if DefendersInTheBox > 7.5
#               if PlayerWeight <= 228.5:
#                 if S <= 7.109999895095825:
#                   if Age <= 35.0:
#                     if Y <= 25.210000038146973:
#                       if A <= 1.2649999856948853:
#                         if PlayerWeight <= 211.5:
#                           if Orientation <= 126.05000305175781:
#                             return [[2. 0.]]
#                           else:  # if Orientation > 126.05000305175781
#                             return [[0. 6.]]
#                         else:  # if PlayerWeight > 211.5
#                           return [[10.  0.]]
#                       else:  # if A > 1.2649999856948853
#                         if Age <= 30.5:
#                           if VisitorScoreBeforePlay <= 13.5:
#                             return [[ 0. 34.]]
#                           else:  # if VisitorScoreBeforePlay > 13.5
#                             if A <= 1.6549999713897705:
#                               if YardsToTouchdown <= 36.5:
#                                 return [[4. 0.]]
#                               else:  # if YardsToTouchdown > 36.5
#                                 return [[0. 1.]]
#                             else:  # if A > 1.6549999713897705
#                               return [[0. 4.]]
#                         else:  # if Age > 30.5
#                           return [[2. 0.]]
#                     else:  # if Y > 25.210000038146973
#                       if X <= 103.5099983215332:
#                         if Y <= 27.545000076293945:
#                           return [[ 0. 51.]]
#                         else:  # if Y > 27.545000076293945
#                           if Season <= 2017.5:
#                             return [[ 0. 23.]]
#                           else:  # if Season > 2017.5
#                             if PlayerWeight <= 207.5:
#                               if Week <= 4.0:
#                                 return [[0. 1.]]
#                               else:  # if Week > 4.0
#                                 return [[5. 0.]]
#                             else:  # if PlayerWeight > 207.5
#                               if Y <= 27.630000114440918:
#                                 return [[2. 0.]]
#                               else:  # if Y > 27.630000114440918
#                                 if PlayerWeight <= 226.5:
#                                   if Week <= 9.0:
#                                     if S <= 4.784999847412109:
#                                       if Cornerbacks <= 2.5:
#                                         return [[1. 0.]]
#                                       else:  # if Cornerbacks > 2.5
#                                         return [[0. 5.]]
#                                     else:  # if S > 4.784999847412109
#                                       return [[ 0. 37.]]
#                                   else:  # if Week > 9.0
#                                     if Age <= 25.5:
#                                       return [[2. 0.]]
#                                     else:  # if Age > 25.5
#                                       return [[0. 5.]]
#                                 else:  # if PlayerWeight > 226.5
#                                   return [[2. 0.]]
#                       else:  # if X > 103.5099983215332
#                         return [[4. 0.]]
#                   else:  # if Age > 35.0
#                     return [[3. 0.]]
#                 else:  # if S > 7.109999895095825
#                   return [[3. 0.]]
#               else:  # if PlayerWeight > 228.5
#                 if A <= 1.6550000309944153:
#                   if Y <= 29.795000076293945:
#                     return [[12.  0.]]
#                   else:  # if Y > 29.795000076293945
#                     return [[0. 1.]]
#                 else:  # if A > 1.6550000309944153
#                   return [[0. 8.]]
#           else:  # if Y > 33.77499961853027
#             if PlayerWeight <= 224.5:
#               return [[7. 0.]]
#             else:  # if PlayerWeight > 224.5
#               return [[0. 2.]]
#       else:  # if A > 1.8550000190734863
#         if YardsToTouchdown <= 2.5:
#           if S <= 3.9450000524520874:
#             if Season <= 2017.5:
#               if StadiumTypeCode <= 1.5:
#                 if Orientation <= 349.39500427246094:
#                   if Y <= 23.119999885559082:
#                     if S <= 2.9649999141693115:
#                       return [[0. 3.]]
#                     else:  # if S > 2.9649999141693115
#                       if A <= 2.8350000381469727:
#                         return [[7. 0.]]
#                       else:  # if A > 2.8350000381469727
#                         return [[0. 1.]]
#                   else:  # if Y > 23.119999885559082
#                     if A <= 2.0999999046325684:
#                       if S <= 3.7450000047683716:
#                         if X <= 14.180000305175781:
#                           return [[0. 2.]]
#                         else:  # if X > 14.180000305175781
#                           return [[8. 0.]]
#                       else:  # if S > 3.7450000047683716
#                         return [[0. 7.]]
#                     else:  # if A > 2.0999999046325684
#                       if VisitorScoreBeforePlay <= 1.5:
#                         return [[ 0. 22.]]
#                       else:  # if VisitorScoreBeforePlay > 1.5
#                         if Y <= 24.9399995803833:
#                           if PlayerWeight <= 208.5:
#                             return [[1. 0.]]
#                           else:  # if PlayerWeight > 208.5
#                             return [[ 0. 28.]]
#                         else:  # if Y > 24.9399995803833
#                           if Age <= 26.5:
#                             if Y <= 27.6850004196167:
#                               return [[3. 0.]]
#                             else:  # if Y > 27.6850004196167
#                               return [[ 0. 17.]]
#                           else:  # if Age > 26.5
#                             if A <= 2.2049999237060547:
#                               return [[0. 1.]]
#                             else:  # if A > 2.2049999237060547
#                               return [[5. 0.]]
#                 else:  # if Orientation > 349.39500427246094
#                   return [[3. 0.]]
#               else:  # if StadiumTypeCode > 1.5
#                 if Week <= 14.0:
#                   return [[ 0. 47.]]
#                 else:  # if Week > 14.0
#                   if HomeScoreBeforePlay <= 8.5:
#                     return [[0. 9.]]
#                   else:  # if HomeScoreBeforePlay > 8.5
#                     if PlayerWeight <= 205.0:
#                       return [[0. 1.]]
#                     else:  # if PlayerWeight > 205.0
#                       return [[3. 0.]]
#             else:  # if Season > 2017.5
#               if Week <= 4.5:
#                 if A <= 2.609999895095825:
#                   if A <= 1.9899999499320984:
#                     return [[0. 2.]]
#                   else:  # if A > 1.9899999499320984
#                     return [[6. 0.]]
#                 else:  # if A > 2.609999895095825
#                   if X <= 103.6449966430664:
#                     if X <= 15.235000133514404:
#                       return [[ 0. 13.]]
#                     else:  # if X > 15.235000133514404
#                       if X <= 15.829999923706055:
#                         return [[3. 0.]]
#                       else:  # if X > 15.829999923706055
#                         if Y <= 24.989999771118164:
#                           return [[ 0. 14.]]
#                         else:  # if Y > 24.989999771118164
#                           if DefendersInTheBox <= 9.0:
#                             if X <= 16.559999465942383:
#                               return [[0. 3.]]
#                             else:  # if X > 16.559999465942383
#                               return [[4. 0.]]
#                           else:  # if DefendersInTheBox > 9.0
#                             return [[0. 6.]]
#                   else:  # if X > 103.6449966430664
#                     return [[ 0. 19.]]
#               else:  # if Week > 4.5
#                 if Dir <= 120.14500045776367:
#                   if PlayerWeight <= 228.5:
#                     return [[15.  0.]]
#                   else:  # if PlayerWeight > 228.5
#                     if A <= 2.8949999809265137:
#                       return [[2. 0.]]
#                     else:  # if A > 2.8949999809265137
#                       return [[0. 3.]]
#                 else:  # if Dir > 120.14500045776367
#                   if HomeScoreBeforePlay <= 8.0:
#                     if Dir <= 246.6449966430664:
#                       return [[8. 0.]]
#                     else:  # if Dir > 246.6449966430664
#                       if Age <= 23.5:
#                         return [[5. 0.]]
#                       else:  # if Age > 23.5
#                         if S <= 3.8299999237060547:
#                           return [[ 0. 10.]]
#                         else:  # if S > 3.8299999237060547
#                           return [[1. 0.]]
#                   else:  # if HomeScoreBeforePlay > 8.0
#                     if DefendersInTheBox <= 6.5:
#                       return [[ 0. 15.]]
#                     else:  # if DefendersInTheBox > 6.5
#                       if A <= 2.8950001001358032:
#                         if Y <= 22.625:
#                           return [[0. 1.]]
#                         else:  # if Y > 22.625
#                           return [[5. 0.]]
#                       else:  # if A > 2.8950001001358032
#                         if S <= 3.2450000047683716:
#                           return [[ 0. 10.]]
#                         else:  # if S > 3.2450000047683716
#                           if Age <= 25.5:
#                             if DefensiveEnds <= 2.5:
#                               return [[0. 7.]]
#                             else:  # if DefensiveEnds > 2.5
#                               return [[2. 0.]]
#                           else:  # if Age > 25.5
#                             return [[2. 0.]]
#           else:  # if S > 3.9450000524520874
#             if X <= 105.29000091552734:
#               if A <= 3.4450000524520874:
#                 if Age <= 33.0:
#                   if X <= 15.724999904632568:
#                     if HomeScoreBeforePlay <= 27.5:
#                       if PlayerHeightInches <= 71.5:
#                         if HomeScoreBeforePlay <= 4.5:
#                           if Week <= 15.0:
#                             return [[ 0. 26.]]
#                           else:  # if Week > 15.0
#                             return [[1. 0.]]
#                         else:  # if HomeScoreBeforePlay > 4.5
#                           if Orientation <= 268.22499084472656:
#                             if Y <= 24.65999984741211:
#                               if Dir <= 226.875:
#                                 return [[0. 5.]]
#                               else:  # if Dir > 226.875
#                                 return [[4. 0.]]
#                             else:  # if Y > 24.65999984741211
#                               return [[ 0. 20.]]
#                           else:  # if Orientation > 268.22499084472656
#                             return [[7. 0.]]
#                       else:  # if PlayerHeightInches > 71.5
#                         if A <= 2.1050000190734863:
#                           if StadiumTypeCode <= 2.0:
#                             return [[0. 4.]]
#                           else:  # if StadiumTypeCode > 2.0
#                             return [[1. 0.]]
#                         else:  # if A > 2.1050000190734863
#                           return [[  0. 102.]]
#                     else:  # if HomeScoreBeforePlay > 27.5
#                       if A <= 3.25:
#                         if A <= 2.01500004529953:
#                           return [[0. 1.]]
#                         else:  # if A > 2.01500004529953
#                           return [[6. 0.]]
#                       else:  # if A > 3.25
#                         return [[0. 4.]]
#                   else:  # if X > 15.724999904632568
#                     if Y <= 21.4350004196167:
#                       return [[6. 0.]]
#                     else:  # if Y > 21.4350004196167
#                       if DefensiveEnds <= 2.5:
#                         if X <= 15.889999866485596:
#                           return [[4. 0.]]
#                         else:  # if X > 15.889999866485596
#                           if VisitorScoreBeforePlay <= 34.0:
#                             if PlayerHeightInches <= 68.5:
#                               if A <= 2.784999966621399:
#                                 return [[6. 0.]]
#                               else:  # if A > 2.784999966621399
#                                 if Y <= 28.570000648498535:
#                                   if Cornerbacks <= 0.5:
#                                     return [[1. 0.]]
#                                   else:  # if Cornerbacks > 0.5
#                                     return [[0. 8.]]
#                                 else:  # if Y > 28.570000648498535
#                                   return [[2. 0.]]
#                             else:  # if PlayerHeightInches > 68.5
#                               if VisitorScoreBeforePlay <= 22.0:
#                                 if A <= 3.319999933242798:
#                                   if Orientation <= 39.255001068115234:
#                                     return [[ 0. 17.]]
#                                   else:  # if Orientation > 39.255001068115234
#                                     if Orientation <= 290.1949920654297:
#                                       if Season <= 2017.5:
#                                         return [[4. 0.]]
#                                       else:  # if Season > 2017.5
#                                         if StadiumTypeCode <= 3.5:
#                                           if Dir <= 41.010000228881836:
#                                             return [[2. 0.]]
#                                           else:  # if Dir > 41.010000228881836
#                                             if S <= 5.690000057220459:
#                                               if A <= 2.2300000190734863:
#                                                 return [[5. 0.]]
#                                               else:  # if A > 2.2300000190734863
#                                                 if X <= 103.43999862670898:
#                                                   if VisitorScoreBeforePlay <= 1.5:
#                                                     if Week <= 3.0:
#                                                       return [[2. 0.]]
#                                                     else:  # if Week > 3.0
#                                                       return [[ 0. 15.]]
#                                                   else:  # if VisitorScoreBeforePlay > 1.5
#                                                     if DefendersInTheBox <= 7.5:
#                                                       if S <= 4.920000076293945:
#                                                         if Age <= 23.5:
#                                                           return [[0. 1.]]
#                                                         else:  # if Age > 23.5
#                                                           return [[3. 0.]]
#                                                       else:  # if S > 4.920000076293945
#                                                         return [[0. 6.]]
#                                                     else:  # if DefendersInTheBox > 7.5
#                                                       return [[10.  0.]]
#                                                 else:  # if X > 103.43999862670898
#                                                   if PlayerWeight <= 221.0:
#                                                     if A <= 2.3700000047683716:
#                                                       return [[3. 0.]]
#                                                     else:  # if A > 2.3700000047683716
#                                                       if Cornerbacks <= 2.5:
#                                                         if S <= 4.609999895095825:
#                                                           return [[ 0. 11.]]
#                                                         else:  # if S > 4.609999895095825
#                                                           if Week <= 8.5:
#                                                             return [[0. 2.]]
#                                                           else:  # if Week > 8.5
#                                                             return [[1. 0.]]
#                                                       else:  # if Cornerbacks > 2.5
#                                                         return [[2. 0.]]
#                                                   else:  # if PlayerWeight > 221.0
#                                                     return [[ 0. 34.]]
#                                             else:  # if S > 5.690000057220459
#                                               return [[ 0. 12.]]
#                                         else:  # if StadiumTypeCode > 3.5
#                                           return [[3. 0.]]
#                                     else:  # if Orientation > 290.1949920654297
#                                       if Orientation <= 325.8299865722656:
#                                         return [[ 0. 23.]]
#                                       else:  # if Orientation > 325.8299865722656
#                                         if Age <= 29.0:
#                                           return [[0. 2.]]
#                                         else:  # if Age > 29.0
#                                           return [[1. 0.]]
#                                 else:  # if A > 3.319999933242798
#                                   if HomeScoreBeforePlay <= 9.5:
#                                     return [[0. 1.]]
#                                   else:  # if HomeScoreBeforePlay > 9.5
#                                     return [[5. 0.]]
#                               else:  # if VisitorScoreBeforePlay > 22.0
#                                 return [[ 0. 14.]]
#                           else:  # if VisitorScoreBeforePlay > 34.0
#                             return [[3. 0.]]
#                       else:  # if DefensiveEnds > 2.5
#                         if X <= 104.95499801635742:
#                           if VisitorScoreBeforePlay <= 29.0:
#                             if A <= 2.225000023841858:
#                               if PlayerWeight <= 224.0:
#                                 return [[1. 0.]]
#                               else:  # if PlayerWeight > 224.0
#                                 return [[0. 1.]]
#                             else:  # if A > 2.225000023841858
#                               if S <= 5.4049999713897705:
#                                 return [[ 0. 52.]]
#                               else:  # if S > 5.4049999713897705
#                                 if DefendersInTheBox <= 10.5:
#                                   return [[0. 6.]]
#                                 else:  # if DefendersInTheBox > 10.5
#                                   return [[1. 0.]]
#                           else:  # if VisitorScoreBeforePlay > 29.0
#                             return [[1. 0.]]
#                         else:  # if X > 104.95499801635742
#                           return [[1. 0.]]
#                 else:  # if Age > 33.0
#                   return [[5. 0.]]
#               else:  # if A > 3.4450000524520874
#                 if Orientation <= 63.51999855041504:
#                   return [[6. 0.]]
#                 else:  # if Orientation > 63.51999855041504
#                   if S <= 4.4750001430511475:
#                     return [[ 0. 69.]]
#                   else:  # if S > 4.4750001430511475
#                     if PlayerHeightInches <= 70.5:
#                       return [[ 0. 34.]]
#                     else:  # if PlayerHeightInches > 70.5
#                       if S <= 5.0350000858306885:
#                         if A <= 6.894999980926514:
#                           if S <= 4.53000020980835:
#                             if Y <= 25.800000190734863:
#                               return [[0. 4.]]
#                             else:  # if Y > 25.800000190734863
#                               return [[1. 0.]]
#                           else:  # if S > 4.53000020980835
#                             return [[ 0. 28.]]
#                         else:  # if A > 6.894999980926514
#                           return [[1. 0.]]
#                       else:  # if S > 5.0350000858306885
#                         if A <= 3.569999933242798:
#                           return [[0. 8.]]
#                         else:  # if A > 3.569999933242798
#                           if S <= 5.56000018119812:
#                             return [[4. 0.]]
#                           else:  # if S > 5.56000018119812
#                             return [[0. 1.]]
#             else:  # if X > 105.29000091552734
#               if X <= 106.40999984741211:
#                 return [[ 0. 66.]]
#               else:  # if X > 106.40999984741211
#                 if X <= 106.61999893188477:
#                   return [[2. 0.]]
#                 else:  # if X > 106.61999893188477
#                   return [[0. 6.]]
#         else:  # if YardsToTouchdown > 2.5
#           if Distance <= 1.5:
#             if Y <= 32.57499885559082:
#               if Season <= 2017.5:
#                 if Dir <= 33.78499984741211:
#                   if VisitorScoreBeforePlay <= 1.5:
#                     return [[4. 0.]]
#                   else:  # if VisitorScoreBeforePlay > 1.5
#                     if A <= 3.09499990940094:
#                       if PlayerWeight <= 208.0:
#                         return [[ 0. 12.]]
#                       else:  # if PlayerWeight > 208.0
#                         return [[5. 0.]]
#                     else:  # if A > 3.09499990940094
#                       return [[ 0. 40.]]
#                 else:  # if Dir > 33.78499984741211
#                   if Dir <= 135.37000274658203:
#                     if A <= 1.9500000476837158:
#                       if Age <= 25.5:
#                         if S <= 2.840000033378601:
#                           return [[1. 0.]]
#                         else:  # if S > 2.840000033378601
#                           return [[ 0. 16.]]
#                       else:  # if Age > 25.5
#                         return [[3. 0.]]
#                     else:  # if A > 1.9500000476837158
#                       if DefendersInTheBox <= 8.5:
#                         if Orientation <= 359.73500061035156:
#                           return [[  0. 371.]]
#                         else:  # if Orientation > 359.73500061035156
#                           return [[1. 0.]]
#                       else:  # if DefendersInTheBox > 8.5
#                         if PlayerWeight <= 215.5:
#                           if S <= 3.4200000762939453:
#                             return [[0. 2.]]
#                           else:  # if S > 3.4200000762939453
#                             return [[2. 0.]]
#                         else:  # if PlayerWeight > 215.5
#                           if A <= 2.0749999284744263:
#                             return [[1. 0.]]
#                           else:  # if A > 2.0749999284744263
#                             return [[ 0. 24.]]
#                   else:  # if Dir > 135.37000274658203
#                     if Dir <= 137.45999908447266:
#                       return [[3. 0.]]
#                     else:  # if Dir > 137.45999908447266
#                       if VisitorScoreBeforePlay <= 30.5:
#                         if PlayerWeight <= 207.0:
#                           return [[ 0. 99.]]
#                         else:  # if PlayerWeight > 207.0
#                           if Dir <= 220.70999908447266:
#                             if Orientation <= 144.30500030517578:
#                               if S <= 4.325000047683716:
#                                 if A <= 2.7050000429153442:
#                                   return [[ 0. 15.]]
#                                 else:  # if A > 2.7050000429153442
#                                   return [[3. 0.]]
#                               else:  # if S > 4.325000047683716
#                                 return [[ 0. 47.]]
#                             else:  # if Orientation > 144.30500030517578
#                               if Dir <= 200.40499877929688:
#                                 return [[ 0. 19.]]
#                               else:  # if Dir > 200.40499877929688
#                                 if Dir <= 211.39500427246094:
#                                   return [[7. 0.]]
#                                 else:  # if Dir > 211.39500427246094
#                                   if Cornerbacks <= 2.5:
#                                     return [[3. 0.]]
#                                   else:  # if Cornerbacks > 2.5
#                                     return [[ 0. 13.]]
#                           else:  # if Dir > 220.70999908447266
#                             if S <= 2.665000081062317:
#                               if Cornerbacks <= 2.5:
#                                 return [[3. 0.]]
#                               else:  # if Cornerbacks > 2.5
#                                 if S <= 2.290000081062317:
#                                   return [[1. 0.]]
#                                 else:  # if S > 2.290000081062317
#                                   return [[ 0. 10.]]
#                             else:  # if S > 2.665000081062317
#                               if Dir <= 335.5400085449219:
#                                 if A <= 2.84499990940094:
#                                   if PlayerWeight <= 209.0:
#                                     if DefendersInTheBox <= 7.5:
#                                       return [[2. 0.]]
#                                     else:  # if DefendersInTheBox > 7.5
#                                       return [[0. 3.]]
#                                   else:  # if PlayerWeight > 209.0
#                                     if X <= 75.42499923706055:
#                                       if YardsToTouchdown <= 20.5:
#                                         if Y <= 30.4399995803833:
#                                           if X <= 34.18499946594238:
#                                             return [[ 0. 40.]]
#                                           else:  # if X > 34.18499946594238
#                                             if VisitorScoreBeforePlay <= 7.0:
#                                               return [[1. 0.]]
#                                             else:  # if VisitorScoreBeforePlay > 7.0
#                                               return [[0. 2.]]
#                                         else:  # if Y > 30.4399995803833
#                                           if Dir <= 302.5550079345703:
#                                             return [[2. 0.]]
#                                           else:  # if Dir > 302.5550079345703
#                                             return [[0. 1.]]
#                                       else:  # if YardsToTouchdown > 20.5
#                                         return [[  0. 190.]]
#                                     else:  # if X > 75.42499923706055
#                                       if Dir <= 319.0249938964844:
#                                         if PlayerHeightInches <= 69.5:
#                                           if VisitorScoreBeforePlay <= 15.0:
#                                             if Cornerbacks <= 1.5:
#                                               return [[0. 1.]]
#                                             else:  # if Cornerbacks > 1.5
#                                               return [[3. 0.]]
#                                           else:  # if VisitorScoreBeforePlay > 15.0
#                                             return [[0. 3.]]
#                                         else:  # if PlayerHeightInches > 69.5
#                                           if A <= 2.7300000190734863:
#                                             return [[ 0. 78.]]
#                                           else:  # if A > 2.7300000190734863
#                                             if X <= 89.80999755859375:
#                                               return [[2. 0.]]
#                                             else:  # if X > 89.80999755859375
#                                               return [[0. 5.]]
#                                       else:  # if Dir > 319.0249938964844
#                                         return [[2. 0.]]
#                                 else:  # if A > 2.84499990940094
#                                   return [[  0. 130.]]
#                               else:  # if Dir > 335.5400085449219
#                                 if PlayerHeightInches <= 71.5:
#                                   return [[ 0. 11.]]
#                                 else:  # if PlayerHeightInches > 71.5
#                                   return [[4. 0.]]
#                       else:  # if VisitorScoreBeforePlay > 30.5
#                         if Week <= 6.0:
#                           return [[0. 3.]]
#                         else:  # if Week > 6.0
#                           return [[4. 0.]]
#               else:  # if Season > 2017.5
#                 if PlayerHeightInches <= 73.5:
#                   if Cornerbacks <= 1.5:
#                     if Dir <= 291.4100036621094:
#                       if YardsToTouchdown <= 73.5:
#                         if YardsToTouchdown <= 49.5:
#                           if Season <= 2018.5:
#                             if DefensiveEnds <= 2.5:
#                               return [[ 0. 15.]]
#                             else:  # if DefensiveEnds > 2.5
#                               return [[1. 0.]]
#                           else:  # if Season > 2018.5
#                             if X <= 40.54499912261963:
#                               return [[0. 6.]]
#                             else:  # if X > 40.54499912261963
#                               return [[7. 0.]]
#                         else:  # if YardsToTouchdown > 49.5
#                           return [[ 0. 38.]]
#                       else:  # if YardsToTouchdown > 73.5
#                         return [[3. 0.]]
#                     else:  # if Dir > 291.4100036621094
#                       return [[3. 0.]]
#                   else:  # if Cornerbacks > 1.5
#                     if YardsToTouchdown <= 54.5:
#                       if PlayerWeight <= 214.5:
#                         if X <= 68.41500091552734:
#                           if Week <= 16.5:
#                             if A <= 3.6950000524520874:
#                               if A <= 3.65500009059906:
#                                 if S <= 3.2699999809265137:
#                                   if Dir <= 276.97999572753906:
#                                     return [[2. 0.]]
#                                   else:  # if Dir > 276.97999572753906
#                                     return [[0. 1.]]
#                                 else:  # if S > 3.2699999809265137
#                                   if Week <= 10.5:
#                                     if Y <= 25.940000534057617:
#                                       if Cornerbacks <= 2.5:
#                                         if Orientation <= 262.2850036621094:
#                                           return [[5. 0.]]
#                                         else:  # if Orientation > 262.2850036621094
#                                           if VisitorScoreBeforePlay <= 6.5:
#                                             return [[1. 0.]]
#                                           else:  # if VisitorScoreBeforePlay > 6.5
#                                             return [[0. 9.]]
#                                       else:  # if Cornerbacks > 2.5
#                                         if PlayerWeight <= 207.0:
#                                           if Dir <= 316.74000549316406:
#                                             return [[ 0. 47.]]
#                                           else:  # if Dir > 316.74000549316406
#                                             if S <= 4.150000095367432:
#                                               return [[1. 0.]]
#                                             else:  # if S > 4.150000095367432
#                                               return [[0. 2.]]
#                                         else:  # if PlayerWeight > 207.0
#                                           if Y <= 23.5:
#                                             return [[0. 6.]]
#                                           else:  # if Y > 23.5
#                                             return [[3. 0.]]
#                                     else:  # if Y > 25.940000534057617
#                                       if X <= 28.875:
#                                         if A <= 2.7450000047683716:
#                                           return [[2. 0.]]
#                                         else:  # if A > 2.7450000047683716
#                                           return [[0. 5.]]
#                                       else:  # if X > 28.875
#                                         return [[ 0. 80.]]
# ...
#                                                             return [[0. 6.]]
#                                                           else:  # if Dir > 240.82500457763672
#                                                             return [[3. 0.]]
#                                                       else:  # if X > 91.57500076293945
#                                                         return [[4. 0.]]
#                                                     else:  # if S > 5.004999876022339
#                                                       return [[5. 0.]]
#                                                 else:  # if S > 5.164999961853027
#                                                   if Dir <= 333.62001037597656:
#                                                     if Dir <= 218.3300018310547:
#                                                       if PlayerHeightInches <= 72.5:
#                                                         return [[4. 0.]]
#                                                       else:  # if PlayerHeightInches > 72.5
#                                                         return [[0. 1.]]
#                                                     else:  # if Dir > 218.3300018310547
#                                                       if PlayerWeight <= 210.5:
#                                                         if Y <= 27.829999923706055:
#                                                           if Dir <= 260.72999572753906:
#                                                             return [[1. 0.]]
#                                                           else:  # if Dir > 260.72999572753906
#                                                             return [[0. 8.]]
#                                                         else:  # if Y > 27.829999923706055
#                                                           return [[3. 0.]]
#                                                       else:  # if PlayerWeight > 210.5
#                                                         if Week <= 14.5:
#                                                           return [[ 0. 41.]]
#                                                         else:  # if Week > 14.5
#                                                           if Y <= 26.914999961853027:
#                                                             return [[0. 3.]]
#                                                           else:  # if Y > 26.914999961853027
#                                                             return [[2. 0.]]
#                                                   else:  # if Dir > 333.62001037597656
#                                                     return [[5. 0.]]
#                                             else:  # if Age > 30.5
#                                               return [[5. 0.]]
#                                       else:  # if HomeScoreBeforePlay > 26.5
#                                         if VisitorScoreBeforePlay <= 22.0:
#                                           return [[14.  0.]]
#                                         else:  # if VisitorScoreBeforePlay > 22.0
#                                           if Dir <= 215.02000427246094:
#                                             return [[2. 0.]]
#                                           else:  # if Dir > 215.02000427246094
#                                             return [[0. 3.]]
#                               else:  # if Y > 29.13499927520752
#                                 if DefensiveEnds <= 0.5:
#                                   if Orientation <= 336.2850036621094:
#                                     return [[25.  0.]]
#                                   else:  # if Orientation > 336.2850036621094
#                                     return [[0. 1.]]
#                                 else:  # if DefensiveEnds > 0.5
#                                   if Week <= 13.5:
#                                     if Orientation <= 337.6499938964844:
#                                       if Y <= 30.035000801086426:
#                                         if VisitorScoreBeforePlay <= 23.5:
#                                           if Week <= 1.5:
#                                             if Cornerbacks <= 3.5:
#                                               return [[2. 0.]]
#                                             else:  # if Cornerbacks > 3.5
#                                               return [[0. 1.]]
#                                           else:  # if Week > 1.5
#                                             return [[16.  0.]]
#                                         else:  # if VisitorScoreBeforePlay > 23.5
#                                           return [[0. 4.]]
#                                       else:  # if Y > 30.035000801086426
#                                         if StadiumTypeCode <= 1.5:
#                                           if Orientation <= 313.8399963378906:
#                                             if Y <= 30.204999923706055:
#                                               return [[ 0. 11.]]
#                                             else:  # if Y > 30.204999923706055
#                                               if Week <= 2.5:
#                                                 return [[ 0. 10.]]
#                                               else:  # if Week > 2.5
#                                                 if Dir <= 283.6300048828125:
#                                                   if Age <= 27.0:
#                                                     return [[8. 0.]]
#                                                   else:  # if Age > 27.0
#                                                     return [[0. 2.]]
#                                                 else:  # if Dir > 283.6300048828125
#                                                   if Dir <= 291.0550079345703:
#                                                     if PlayerHeightInches <= 68.5:
#                                                       return [[1. 0.]]
#                                                     else:  # if PlayerHeightInches > 68.5
#                                                       return [[ 0. 16.]]
#                                                   else:  # if Dir > 291.0550079345703
#                                                     if Dir <= 323.0500030517578:
#                                                       return [[7. 0.]]
#                                                     else:  # if Dir > 323.0500030517578
#                                                       if X <= 79.04999923706055:
#                                                         return [[0. 5.]]
#                                                       else:  # if X > 79.04999923706055
#                                                         return [[1. 0.]]
#                                           else:  # if Orientation > 313.8399963378906
#                                             return [[5. 0.]]
#                                         else:  # if StadiumTypeCode > 1.5
#                                           if Orientation <= 318.6899871826172:
#                                             return [[15.  0.]]
#                                           else:  # if Orientation > 318.6899871826172
#                                             if S <= 5.0899999141693115:
#                                               return [[2. 0.]]
#                                             else:  # if S > 5.0899999141693115
#                                               return [[0. 7.]]
#                                     else:  # if Orientation > 337.6499938964844
#                                       return [[8. 0.]]
#                                   else:  # if Week > 13.5
#                                     return [[13.  0.]]
#                             else:  # if Y > 32.65999984741211
#                               return [[ 0. 12.]]
#                           else:  # if Y > 32.795000076293945
#                             return [[12.  0.]]
#               else:  # if Cornerbacks > 5.5
#                 return [[0. 9.]]
#             else:  # if DefendersInTheBox > 7.5
#               if PlayerWeight <= 196.0:
#                 return [[20.  0.]]
#               else:  # if PlayerWeight > 196.0
#                 if A <= 3.3049999475479126:
#                   if S <= 4.984999895095825:
#                     if VisitorScoreBeforePlay <= 18.0:
#                       if S <= 4.5950000286102295:
#                         if Y <= 29.844999313354492:
#                           return [[2. 0.]]
#                         else:  # if Y > 29.844999313354492
#                           return [[0. 7.]]
#                       else:  # if S > 4.5950000286102295
#                         if HomeScoreBeforePlay <= 1.5:
#                           if PlayerWeight <= 211.5:
#                             return [[0. 4.]]
#                           else:  # if PlayerWeight > 211.5
#                             if YardsToTouchdown <= 20.0:
#                               return [[0. 1.]]
#                             else:  # if YardsToTouchdown > 20.0
#                               return [[10.  0.]]
#                         else:  # if HomeScoreBeforePlay > 1.5
#                           if X <= 94.63000106811523:
#                             return [[32.  0.]]
#                           else:  # if X > 94.63000106811523
#                             if S <= 4.730000019073486:
#                               return [[0. 1.]]
#                             else:  # if S > 4.730000019073486
#                               return [[2. 0.]]
#                     else:  # if VisitorScoreBeforePlay > 18.0
#                       if YardsToTouchdown <= 44.5:
#                         if YardsToTouchdown <= 8.5:
#                           return [[0. 2.]]
#                         else:  # if YardsToTouchdown > 8.5
#                           return [[2. 0.]]
#                       else:  # if YardsToTouchdown > 44.5
#                         return [[ 0. 16.]]
#                   else:  # if S > 4.984999895095825
#                     if Orientation <= 67.64500045776367:
#                       if Y <= 24.304999351501465:
#                         return [[0. 2.]]
#                       else:  # if Y > 24.304999351501465
#                         return [[7. 0.]]
#                     else:  # if Orientation > 67.64500045776367
#                       return [[50.  0.]]
#                 else:  # if A > 3.3049999475479126
#                   if Y <= 26.945000648498535:
#                     if VisitorScoreBeforePlay <= 13.5:
#                       if S <= 5.305000066757202:
#                         return [[28.  0.]]
#                       else:  # if S > 5.305000066757202
#                         if Dir <= 192.2199935913086:
#                           if PlayerHeightInches <= 69.5:
#                             return [[1. 0.]]
#                           else:  # if PlayerHeightInches > 69.5
#                             return [[0. 3.]]
#                         else:  # if Dir > 192.2199935913086
#                           return [[7. 0.]]
#                     else:  # if VisitorScoreBeforePlay > 13.5
#                       if A <= 3.6850000619888306:
#                         return [[4. 0.]]
#                       else:  # if A > 3.6850000619888306
#                         if Season <= 2018.5:
#                           if Y <= 26.364999771118164:
#                             return [[ 0. 13.]]
#                           else:  # if Y > 26.364999771118164
#                             return [[2. 0.]]
#                         else:  # if Season > 2018.5
#                           return [[3. 0.]]
#                   else:  # if Y > 26.945000648498535
#                     if X <= 26.155000686645508:
#                       if Orientation <= 26.0649995803833:
#                         return [[1. 0.]]
#                       else:  # if Orientation > 26.0649995803833
#                         return [[ 0. 16.]]
#                     else:  # if X > 26.155000686645508
#                       if Age <= 22.5:
#                         return [[11.  0.]]
#                       else:  # if Age > 22.5
#                         if S <= 4.909999847412109:
#                           if S <= 4.634999990463257:
#                             if Dir <= 163.0449981689453:
#                               return [[4. 0.]]
#                             else:  # if Dir > 163.0449981689453
#                               return [[0. 7.]]
#                           else:  # if S > 4.634999990463257
#                             return [[10.  0.]]
#                         else:  # if S > 4.909999847412109
#                           if Age <= 27.5:
#                             if S <= 5.414999961853027:
#                               if X <= 90.01499938964844:
#                                 return [[0. 9.]]
#                               else:  # if X > 90.01499938964844
#                                 if A <= 3.5399999618530273:
#                                   return [[3. 0.]]
#                                 else:  # if A > 3.5399999618530273
#                                   return [[0. 2.]]
#                             else:  # if S > 5.414999961853027
#                               return [[3. 0.]]
#                           else:  # if Age > 27.5
#                             return [[ 0. 15.]]
#         else:  # if Distance > 11.5
#           if X <= 82.61000061035156:
#             if Orientation <= 301.10499572753906:
#               if HomeScoreBeforePlay <= 1.5:
#                 return [[44.  0.]]
#               else:  # if HomeScoreBeforePlay > 1.5
#                 if A <= 5.920000076293945:
#                   if VisitorScoreBeforePlay <= 5.5:
#                     return [[33.  0.]]
#                   else:  # if VisitorScoreBeforePlay > 5.5
#                     if Week <= 11.5:
#                       if A <= 3.6350001096725464:
#                         return [[35.  0.]]
#                       else:  # if A > 3.6350001096725464
#                         if DefendersInTheBox <= 6.5:
#                           if A <= 3.665000081062317:
#                             return [[0. 1.]]
#                           else:  # if A > 3.665000081062317
#                             return [[15.  0.]]
#                         else:  # if DefendersInTheBox > 6.5
#                           if PlayerWeight <= 205.0:
#                             return [[0. 4.]]
#                           else:  # if PlayerWeight > 205.0
#                             return [[2. 0.]]
#                     else:  # if Week > 11.5
#                       if HomeScoreBeforePlay <= 16.0:
#                         if HomeScoreBeforePlay <= 7.5:
#                           return [[0. 3.]]
#                         else:  # if HomeScoreBeforePlay > 7.5
#                           if PlayerHeightInches <= 70.5:
#                             return [[6. 0.]]
#                           else:  # if PlayerHeightInches > 70.5
#                             if Age <= 25.5:
#                               if Dir <= 309.6000061035156:
#                                 return [[0. 5.]]
#                               else:  # if Dir > 309.6000061035156
#                                 return [[1. 0.]]
#                             else:  # if Age > 25.5
#                               return [[2. 0.]]
#                       else:  # if HomeScoreBeforePlay > 16.0
#                         return [[8. 0.]]
#                 else:  # if A > 5.920000076293945
#                   return [[0. 3.]]
#             else:  # if Orientation > 301.10499572753906
#               if Orientation <= 307.52500915527344:
#                 if S <= 4.715000033378601:
#                   return [[0. 9.]]
#                 else:  # if S > 4.715000033378601
#                   return [[1. 0.]]
#               else:  # if Orientation > 307.52500915527344
#                 if S <= 5.375:
#                   return [[8. 0.]]
#                 else:  # if S > 5.375
#                   return [[0. 2.]]
#           else:  # if X > 82.61000061035156
#             return [[67.  0.]]
