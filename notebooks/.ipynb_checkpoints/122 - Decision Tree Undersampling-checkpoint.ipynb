# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier #Import scikit-Tree For Decision Tree
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import classification_report,confusion_matrix #import Confusion Matrix
from sklearn.model_selection import train_test_split # Splitting the data
from sklearn import preprocessing # Normalizing

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot 
import time
# Out:
# D:\Users\sourc\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
df_o = pd.read_csv("../data/processed/data_undersampled.csv",index_col=0)

# %%
# Normalizing the data
x = df_o.values #returns a numpy array
col = df_o.columns
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_n = pd.DataFrame(x_scaled, columns = col)

df_n
# Out:
#               X         Y  Orientation       Dir  PossessionTeamAbbrCode  \
# 0      0.810724  0.470166     0.755453  0.714254                0.967742
# 1      0.915307  0.525773     0.739615  0.520172                0.225806
# 2      0.591659  0.544205     0.674123  0.701945                0.645161
# 3      0.303391  0.540769     0.947151  0.202612                0.548387
# 4      0.237030  0.474539     0.464447  0.965435                0.838710
# ...         ...       ...          ...       ...                     ...
# 11953  0.701283  0.411434     0.157131  0.210281                0.064516
# 11954  0.247846  0.398313     0.141821  0.228202                0.064516
# 11955  0.315490  0.539519     0.268638  0.328786                0.064516
# 11956  0.602383  0.639175     0.137625  0.147930                0.516129
# 11957  0.586068  0.574820     0.840479  0.791775                0.064516
#
#        HomeScoreBeforePlay  VisitorScoreBeforePlay  PlayerHeightInches  \
# 0                 0.122807                0.000000            0.222222
# 1                 0.175439                0.000000            0.555556
# 2                 0.473684                0.338983            0.444444
# 3                 0.000000                0.000000            0.444444
# 4                 0.000000                0.101695            0.777778
# ...                    ...                     ...                 ...
# 11953             0.105263                0.474576            0.777778
# 11954             0.105263                0.593220            0.333333
# 11955             0.105263                0.593220            0.333333
# 11956             0.105263                0.711864            0.777778
# 11957             0.105263                0.711864            0.777778
#
#        PlayerWeight  PlayerCollegeNameCode  VisitorTeamAbbrCode    Week  \
# 0          0.166667               0.166078             0.967742  0.5000
# 1          0.583333               0.007067             0.225806  0.7500
# 2          0.444444               0.148410             0.387097  0.0000
# 3          0.236111               0.844523             0.548387  0.6875
# 4          0.694444               0.166078             0.838710  0.1875
# ...             ...                    ...                  ...     ...
# 11953      0.763889               0.127208             0.064516  0.6875
# 11954      0.444444               0.130742             0.064516  0.6875
# 11955      0.444444               0.130742             0.064516  0.6875
# 11956      0.569444               0.007067             0.064516  0.6875
# 11957      0.763889               0.127208             0.064516  0.6875
#
#        isFirstDown  DefensiveEnds  DefensiveTackles
# 0              0.0           0.50               0.4
# 1              0.0           0.75               0.2
# 2              0.0           0.50               0.4
# 3              0.0           0.75               0.2
# 4              0.0           0.00               0.2
# ...            ...            ...               ...
# 11953          1.0           0.00               0.6
# 11954          1.0           0.00               0.6
# 11955          1.0           0.00               0.6
# 11956          1.0           0.00               0.4
# 11957          1.0           0.00               0.8
#
# [11958 rows x 15 columns]

# %%
X = df_o.drop("isFirstDown",1)   #Feature Matrix
y = df_o["isFirstDown"]          #Target Variable

# %%
# from sklearn.model_selection import train_test_split # Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=72)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8370, 14)
# (3588, 14)
# (8370,)
# (3588,)

# %%
# Create Decision Tree classifer object
dtree = DecisionTreeClassifier(criterion="entropy")

# %%
# Train Decision Tree Classifer
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#Predict the response for test dataset
y_pred = dtree.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %0.2f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %0.2f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %0.2f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred)
print('F1 score: %0.2f' % f1)

acc = pd.read_csv("../data/external/accuracies.csv", index_col=0)
acc.at['Decision Tree, Undersampled', 'Accuracy'] = accuracy
acc.at['Decision Tree, Undersampled', 'Precision'] = precision
acc.at['Decision Tree, Undersampled', 'Recall'] = recall
acc.at['Decision Tree, Undersampled', 'F1'] = f1
acc.to_csv("../data/external/accuracies.csv")
# Out:
# Accuracy: 0.51
# Precision: 0.50
# Recall: 0.52
# F1 score: 0.51

# %%
#Present Confusion Matrix to show accuracy
print(classification_report(y_test,y_pred),'\n',confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.50      0.51      1821
#            1       0.50      0.52      0.51      1767
#
#     accuracy                           0.51      3588
#    macro avg       0.51      0.51      0.51      3588
# weighted avg       0.51      0.51      0.51      3588
#
#  [[915 906]
#  [845 922]]

# %%
features = list(X)
#features

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True,rotate=True, max_depth=3)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png(), width=7860, height=2160)
