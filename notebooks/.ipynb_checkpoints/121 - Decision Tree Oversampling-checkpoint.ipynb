# %% [markdown]
# # Decision Tree - Oversampling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier #Import scikit-Tree For Decision Tree
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import classification_report,confusion_matrix #import Confusion Matrix
from sklearn.model_selection import train_test_split # Splitting the data
from sklearn import preprocessing # Normalizing

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import time
# Out:
# D:\Users\sourc\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
df_o = pd.read_csv("../data/processed/data_oversampled.csv",index_col=0)

# %%
# Normalizing the data
x = df_o.values #returns a numpy array
col = df_o.columns
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_n = pd.DataFrame(x_scaled, columns = col)

# df_n

# %%
X = df_o.drop("isFirstDown",1)   #Feature Matrix
y = df_o["isFirstDown"]          #Target Variable

# %%
# from sklearn.model_selection import train_test_split # Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=72)

numDimensions = X_test.shape[1]

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (31544, 25)
# (13520, 25)
# (31544,)
# (13520,)

# %%
# Create Decision Tree classifer object
dtree = DecisionTreeClassifier(criterion="entropy")

# %%
# Train Decision Tree Classifer
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#Predict the response for test dataset
y_pred = dtree.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred)
print('F1 score: %f' % f1)

acc = pd.read_csv("../data/external/accuracies.csv", index_col=0)
acc.at['Decision Tree, Oversampled', 'Accuracy'] = accuracy
acc.at['Decision Tree, Oversampled', 'Precision'] = precision
acc.at['Decision Tree, Oversampled', 'Recall'] = recall
acc.at['Decision Tree, Oversampled', 'F1'] = f1
acc.to_csv("../data/external/accuracies.csv")
# Out:
# Accuracy: 0.874408
# Precision: 0.822169
# Recall: 0.958535
# F1 score: 0.885131

# %%
#Present Confusion Matrix to show accuracy
print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#
# [[5280 1415]
#  [ 283 6542]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86      6695
#            1       0.82      0.96      0.89      6825
#
#     accuracy                           0.87     13520
#    macro avg       0.89      0.87      0.87     13520
# weighted avg       0.89      0.87      0.87     13520

# %%
features = list(X)
#features

# %%
# dot_data = StringIO()  
# export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True,rotate=True, max_depth=3)

# import pydot
# graph = pydot.graph_from_dot_data(dot_data.getvalue())  
# Image(graph[0].create_png(), width=7860, height=2160)

# %%
from sklearn.tree import _tree

def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [ \
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!" \
        for i in tree_.feature \
    ]
    print("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "  " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            print("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print("{}return {}".format(indent, tree_.value[node]))

    recurse(0, 1)
    
tree_to_code(dtree, features)
# Out:
# def tree(Cornerbacks, Centers, isHomeTeam, DefensiveEnds, NoseTackles, PlayerHeightInches, TurfCode, S, Down, Age, TightEnds, IsPossTeamInLead, isPlayDirectionLeft, Quarter, DefensiveTackles, OffensiveGuards, A, Distance, StadiumTypeCode, LineBackers, DefendersInTheBox, Season, Safeties, DistanceBins, TimeSnapDiff):
#   if DistanceBins <= 1.5:
#     if Distance <= 2.5:
#       if A <= 1.8550000190734863:
#         if S <= 4.120000123977661:
#           if A <= 1.5149999856948853:
#             if Distance <= 1.5:
#               if Season <= 2017.5:
#                 if NoseTackles <= 0.5:
#                   if S <= 2.4600000381469727:
#                     return [[9. 0.]]
#                   else:  # if S > 2.4600000381469727
#                     if PlayerHeightInches <= 69.5:
#                       if LineBackers <= 2.5:
#                         return [[4. 0.]]
#                       else:  # if LineBackers > 2.5
#                         if Centers <= 1.5:
#                           return [[ 0. 20.]]
#                         else:  # if Centers > 1.5
#                           return [[1. 0.]]
#                     else:  # if PlayerHeightInches > 69.5
#                       if PlayerHeightInches <= 71.5:
#                         if S <= 3.930000066757202:
#                           return [[15.  0.]]
#                         else:  # if S > 3.930000066757202
#                           return [[0. 1.]]
#                       else:  # if PlayerHeightInches > 71.5
#                         if S <= 3.259999990463257:
#                           if Age <= 28.0:
#                             if TimeSnapDiff <= 1.5:
#                               if S <= 3.0749999284744263:
#                                 if DefensiveEnds <= 1.5:
#                                   if S <= 2.944999933242798:
#                                     if Centers <= 2.5:
#                                       if Age <= 26.5:
#                                         return [[ 0. 10.]]
#                                       else:  # if Age > 26.5
#                                         if S <= 2.7549999952316284:
#                                           return [[1. 0.]]
#                                         else:  # if S > 2.7549999952316284
#                                           return [[0. 3.]]
#                                     else:  # if Centers > 2.5
#                                       return [[1. 0.]]
#                                   else:  # if S > 2.944999933242798
#                                     return [[1. 0.]]
#                                 else:  # if DefensiveEnds > 1.5
#                                   return [[2. 0.]]
#                               else:  # if S > 3.0749999284744263
#                                 return [[ 0. 12.]]
#                             else:  # if TimeSnapDiff > 1.5
#                               return [[3. 0.]]
#                           else:  # if Age > 28.0
#                             return [[4. 0.]]
#                         else:  # if S > 3.259999990463257
#                           if S <= 3.680000066757202:
#                             return [[12.  0.]]
#                           else:  # if S > 3.680000066757202
#                             if S <= 3.7350000143051147:
#                               return [[0. 3.]]
#                             else:  # if S > 3.7350000143051147
#                               return [[1. 0.]]
#                 else:  # if NoseTackles > 0.5
#                   if DefendersInTheBox <= 8.5:
#                     if OffensiveGuards <= 2.5:
#                       if S <= 3.1999999284744263:
#                         if S <= 2.5950000286102295:
#                           if isPlayDirectionLeft <= 0.5:
#                             return [[ 0. 18.]]
#                           else:  # if isPlayDirectionLeft > 0.5
#                             return [[1. 0.]]
#                         else:  # if S > 2.5950000286102295
#                           if LineBackers <= 3.5:
#                             return [[3. 0.]]
#                           else:  # if LineBackers > 3.5
#                             return [[0. 1.]]
#                       else:  # if S > 3.1999999284744263
#                         return [[ 0. 18.]]
#                     else:  # if OffensiveGuards > 2.5
#                       if isPlayDirectionLeft <= 0.5:
#                         return [[3. 0.]]
#                       else:  # if isPlayDirectionLeft > 0.5
#                         return [[0. 1.]]
#                   else:  # if DefendersInTheBox > 8.5
#                     if A <= 1.2950000166893005:
#                       return [[8. 0.]]
#                     else:  # if A > 1.2950000166893005
#                       if Cornerbacks <= 1.0:
#                         return [[1. 0.]]
#                       else:  # if Cornerbacks > 1.0
#                         return [[0. 2.]]
#               else:  # if Season > 2017.5
#                 if S <= 4.075000047683716:
#                   if DefensiveEnds <= 1.5:
#                     if LineBackers <= 2.5:
#                       if TurfCode <= 1.5:
#                         return [[0. 2.]]
#                       else:  # if TurfCode > 1.5
#                         return [[1. 0.]]
#                     else:  # if LineBackers > 2.5
#                       return [[ 0. 33.]]
#                   else:  # if DefensiveEnds > 1.5
#                     if S <= 4.025000095367432:
#                       if Age <= 25.5:
#                         if Quarter <= 1.5:
#                           return [[ 0. 10.]]
#                         else:  # if Quarter > 1.5
#                           if S <= 3.5649999380111694:
#                             if S <= 2.634999990463257:
#                               return [[1. 0.]]
#                             else:  # if S > 2.634999990463257
#                               return [[0. 4.]]
#                           else:  # if S > 3.5649999380111694
#                             return [[4. 0.]]
#                       else:  # if Age > 25.5
#                         return [[4. 0.]]
#                     else:  # if S > 4.025000095367432
#                       return [[ 0. 10.]]
#                 else:  # if S > 4.075000047683716
#                   return [[3. 0.]]
#             else:  # if Distance > 1.5
#               if isPlayDirectionLeft <= 0.5:
#                 return [[16.  0.]]
#               else:  # if isPlayDirectionLeft > 0.5
#                 if A <= 0.7249999940395355:
#                   if DefendersInTheBox <= 8.5:
#                     return [[0. 6.]]
#                   else:  # if DefendersInTheBox > 8.5
#                     return [[2. 0.]]
#                 else:  # if A > 0.7249999940395355
#                   if DefendersInTheBox <= 6.5:
#                     if IsPossTeamInLead <= 0.5:
#                       return [[1. 0.]]
#                     else:  # if IsPossTeamInLead > 0.5
#                       return [[0. 3.]]
#                   else:  # if DefendersInTheBox > 6.5
#                     if Centers <= 0.5:
#                       if DefensiveEnds <= 1.5:
#                         return [[1. 0.]]
#                       else:  # if DefensiveEnds > 1.5
#                         return [[0. 1.]]
#                     else:  # if Centers > 0.5
#                       return [[14.  0.]]
#           else:  # if A > 1.5149999856948853
#             if A <= 1.8450000286102295:
#               if OffensiveGuards <= 3.5:
#                 if A <= 1.5549999475479126:
#                   return [[ 0. 15.]]
#                 else:  # if A > 1.5549999475479126
#                   if isHomeTeam <= 0.5:
#                     if Down <= 1.5:
#                       return [[4. 0.]]
#                     else:  # if Down > 1.5
#                       if Age <= 28.5:
#                         if DefensiveEnds <= 2.5:
#                           if Distance <= 1.5:
#                             if TimeSnapDiff <= 1.5:
#                               if A <= 1.6850000023841858:
#                                 if A <= 1.5699999928474426:
#                                   if DefensiveTackles <= 1.5:
#                                     return [[1. 0.]]
#                                   else:  # if DefensiveTackles > 1.5
#                                     return [[0. 2.]]
#                                 else:  # if A > 1.5699999928474426
#                                   return [[ 0. 21.]]
#                               else:  # if A > 1.6850000023841858
#                                 if DefensiveTackles <= 1.5:
#                                   return [[3. 0.]]
#                                 else:  # if DefensiveTackles > 1.5
#                                   if Safeties <= 1.5:
#                                     return [[2. 0.]]
#                                   else:  # if Safeties > 1.5
#                                     if DefensiveTackles <= 2.5:
#                                       return [[ 0. 11.]]
#                                     else:  # if DefensiveTackles > 2.5
#                                       if Down <= 3.5:
#                                         return [[2. 0.]]
#                                       else:  # if Down > 3.5
#                                         return [[0. 2.]]
#                             else:  # if TimeSnapDiff > 1.5
#                               return [[ 0. 16.]]
#                           else:  # if Distance > 1.5
#                             if StadiumTypeCode <= 1.5:
#                               if A <= 1.7600000500679016:
#                                 return [[6. 0.]]
#                               else:  # if A > 1.7600000500679016
#                                 return [[0. 1.]]
#                             else:  # if StadiumTypeCode > 1.5
#                               if LineBackers <= 3.5:
#                                 return [[0. 7.]]
#                               else:  # if LineBackers > 3.5
#                                 return [[1. 0.]]
#                         else:  # if DefensiveEnds > 2.5
#                           return [[2. 0.]]
#                       else:  # if Age > 28.5
#                         if A <= 1.784999966621399:
#                           return [[8. 0.]]
#                         else:  # if A > 1.784999966621399
#                           if A <= 1.8300000429153442:
#                             return [[0. 5.]]
#                           else:  # if A > 1.8300000429153442
#                             return [[1. 0.]]
#                   else:  # if isHomeTeam > 0.5
#                     if TurfCode <= 1.5:
#                       if PlayerHeightInches <= 74.5:
#                         if Down <= 2.5:
#                           if isPlayDirectionLeft <= 0.5:
#                             if Age <= 27.5:
#                               return [[4. 0.]]
#                             else:  # if Age > 27.5
#                               return [[0. 4.]]
#                           else:  # if isPlayDirectionLeft > 0.5
#                             if DefensiveTackles <= 0.5:
#                               if IsPossTeamInLead <= 0.5:
#                                 return [[0. 2.]]
#                               else:  # if IsPossTeamInLead > 0.5
#                                 return [[2. 0.]]
#                             else:  # if DefensiveTackles > 0.5
#                               if Quarter <= 1.5:
#                                 return [[1. 0.]]
#                               else:  # if Quarter > 1.5
#                                 return [[ 0. 34.]]
#                         else:  # if Down > 2.5
#                           return [[ 0. 31.]]
#                       else:  # if PlayerHeightInches > 74.5
#                         return [[2. 0.]]
#                     else:  # if TurfCode > 1.5
#                       if A <= 1.7350000143051147:
#                         if Down <= 1.5:
#                           return [[4. 0.]]
#                         else:  # if Down > 1.5
#                           if DefendersInTheBox <= 7.5:
#                             if S <= 3.340000033378601:
#                               if Centers <= 1.5:
#                                 return [[3. 0.]]
#                               else:  # if Centers > 1.5
#                                 return [[0. 5.]]
#                             else:  # if S > 3.340000033378601
#                               return [[ 0. 10.]]
#                           else:  # if DefendersInTheBox > 7.5
#                             return [[ 0. 29.]]
#                       else:  # if A > 1.7350000143051147
#                         if isPlayDirectionLeft <= 0.5:
#                           return [[7. 0.]]
#                         else:  # if isPlayDirectionLeft > 0.5
#                           if A <= 1.8049999475479126:
#                             if Down <= 3.5:
#                               return [[4. 0.]]
#                             else:  # if Down > 3.5
#                               return [[0. 1.]]
#                           else:  # if A > 1.8049999475479126
#                             return [[0. 2.]]
#               else:  # if OffensiveGuards > 3.5
#                 return [[2. 0.]]
#             else:  # if A > 1.8450000286102295
#               return [[3. 0.]]
#         else:  # if S > 4.120000123977661
#           if DefendersInTheBox <= 7.5:
#             if S <= 7.924999952316284:
#               if Distance <= 1.5:
#                 if Season <= 2018.5:
#                   if S <= 6.019999980926514:
#                     if Centers <= 0.5:
#                       if TurfCode <= 1.5:
#                         return [[0. 1.]]
#                       else:  # if TurfCode > 1.5
#                         return [[2. 0.]]
#                     else:  # if Centers > 0.5
#                       if PlayerHeightInches <= 67.0:
#                         return [[1. 0.]]
#                       else:  # if PlayerHeightInches > 67.0
#                         if A <= 0.8700000047683716:
#                           if Cornerbacks <= 2.5:
#                             return [[2. 0.]]
#                           else:  # if Cornerbacks > 2.5
#                             return [[0. 5.]]
#                         else:  # if A > 0.8700000047683716
#                           if A <= 1.3949999809265137:
#                             return [[ 0. 37.]]
#                           else:  # if A > 1.3949999809265137
#                             if OffensiveGuards <= 1.5:
#                               if S <= 4.8399999141693115:
#                                 if A <= 1.4599999785423279:
#                                   return [[0. 3.]]
#                                 else:  # if A > 1.4599999785423279
#                                   if Age <= 21.5:
#                                     return [[0. 1.]]
#                                   else:  # if Age > 21.5
#                                     return [[3. 0.]]
#                               else:  # if S > 4.8399999141693115
#                                 return [[0. 6.]]
#                             else:  # if OffensiveGuards > 1.5
#                               if A <= 1.4300000071525574:
#                                 return [[1. 0.]]
#                               else:  # if A > 1.4300000071525574
#                                 return [[ 0. 53.]]
#                   else:  # if S > 6.019999980926514
#                     if DefendersInTheBox <= 6.5:
#                       return [[0. 4.]]
#                     else:  # if DefendersInTheBox > 6.5
#                       return [[4. 0.]]
#                 else:  # if Season > 2018.5
#                   if A <= 1.0600000023841858:
#                     if TurfCode <= 1.5:
#                       return [[1. 0.]]
#                     else:  # if TurfCode > 1.5
#                       return [[ 0. 14.]]
#                   else:  # if A > 1.0600000023841858
#                     return [[ 0. 60.]]
#               else:  # if Distance > 1.5
#                 if Season <= 2017.5:
#                   return [[4. 0.]]
#                 else:  # if Season > 2017.5
#                   if isHomeTeam <= 0.5:
#                     if A <= 1.7300000190734863:
#                       if A <= 1.3100000023841858:
#                         if DefendersInTheBox <= 6.5:
#                           if Centers <= 1.5:
#                             if Cornerbacks <= 3.5:
#                               return [[5. 0.]]
#                             else:  # if Cornerbacks > 3.5
#                               return [[0. 4.]]
#                           else:  # if Centers > 1.5
#                             return [[0. 9.]]
#                         else:  # if DefendersInTheBox > 6.5
#                           return [[ 0. 20.]]
#                       else:  # if A > 1.3100000023841858
#                         return [[ 0. 49.]]
#                     else:  # if A > 1.7300000190734863
#                       if S <= 4.704999923706055:
#                         return [[0. 5.]]
#                       else:  # if S > 4.704999923706055
#                         return [[3. 0.]]
#                   else:  # if isHomeTeam > 0.5
#                     if A <= 1.7949999570846558:
#                       if TimeSnapDiff <= 1.5:
#                         if S <= 5.324999809265137:
#                           if isPlayDirectionLeft <= 0.5:
#                             if PlayerHeightInches <= 71.5:
#                               return [[2. 0.]]
#                             else:  # if PlayerHeightInches > 71.5
#                               return [[0. 7.]]
#                           else:  # if isPlayDirectionLeft > 0.5
#                             return [[4. 0.]]
#                         else:  # if S > 5.324999809265137
#                           return [[ 0. 14.]]
#                       else:  # if TimeSnapDiff > 1.5
#                         if A <= 0.48000000417232513:
#                           return [[0. 1.]]
#                         else:  # if A > 0.48000000417232513
#                           return [[4. 0.]]
#                     else:  # if A > 1.7949999570846558
#                       return [[0. 6.]]
#             else:  # if S > 7.924999952316284
#               return [[2. 0.]]
#           else:  # if DefendersInTheBox > 7.5
#             if S <= 7.109999895095825:
#               if Age <= 35.0:
#                 if DefensiveEnds <= 2.5:
#                   if DefensiveTackles <= 1.5:
#                     if Age <= 26.5:
#                       if Safeties <= 2.5:
#                         if S <= 5.485000133514404:
#                           if isPlayDirectionLeft <= 0.5:
#                             return [[4. 0.]]
#                           else:  # if isPlayDirectionLeft > 0.5
#                             if S <= 5.085000038146973:
#                               if Quarter <= 2.0:
#                                 return [[1. 0.]]
#                               else:  # if Quarter > 2.0
#                                 return [[ 0. 13.]]
#                             else:  # if S > 5.085000038146973
#                               return [[2. 0.]]
#                         else:  # if S > 5.485000133514404
#                           return [[ 0. 14.]]
#                       else:  # if Safeties > 2.5
#                         return [[2. 0.]]
#                     else:  # if Age > 26.5
#                       if TurfCode <= 2.5:
#                         return [[ 0. 36.]]
#                       else:  # if TurfCode > 2.5
#                         return [[1. 0.]]
#                   else:  # if DefensiveTackles > 1.5
#                     if A <= 0.675000011920929:
#                       if LineBackers <= 3.5:
#                         return [[4. 0.]]
#                       else:  # if LineBackers > 3.5
#                         return [[0. 1.]]
#                     else:  # if A > 0.675000011920929
#                       if TurfCode <= 2.5:
#                         if S <= 4.1549999713897705:
#                           return [[2. 0.]]
#                         else:  # if S > 4.1549999713897705
#                           if isHomeTeam <= 0.5:
#                             if TimeSnapDiff <= 1.5:
#                               if A <= 1.5850000381469727:
#                                 if Quarter <= 1.5:
#                                   return [[1. 0.]]
#                                 else:  # if Quarter > 1.5
#                                   if Down <= 3.5:
#                                     if PlayerHeightInches <= 72.5:
#                                       return [[ 0. 22.]]
#                                     else:  # if PlayerHeightInches > 72.5
#                                       if Distance <= 1.5:
#                                         return [[0. 2.]]
#                                       else:  # if Distance > 1.5
#                                         return [[1. 0.]]
#                                   else:  # if Down > 3.5
#                                     return [[1. 0.]]
#                               else:  # if A > 1.5850000381469727
#                                 if Age <= 26.5:
#                                   return [[6. 0.]]
#                                 else:  # if Age > 26.5
#                                   return [[0. 3.]]
#                             else:  # if TimeSnapDiff > 1.5
#                               if A <= 1.6100000143051147:
#                                 return [[7. 0.]]
#                               else:  # if A > 1.6100000143051147
#                                 return [[0. 1.]]
#                           else:  # if isHomeTeam > 0.5
#                             if S <= 5.820000171661377:
#                               if NoseTackles <= 0.5:
#                                 if Quarter <= 3.5:
#                                   if Cornerbacks <= 2.5:
#                                     return [[ 0. 38.]]
#                                   else:  # if Cornerbacks > 2.5
#                                     return [[1. 0.]]
#                                 else:  # if Quarter > 3.5
#                                   if OffensiveGuards <= 2.5:
#                                     if A <= 1.75:
#                                       return [[0. 8.]]
#                                     else:  # if A > 1.75
#                                       return [[1. 0.]]
#                                   else:  # if OffensiveGuards > 2.5
#                                     return [[2. 0.]]
#                               else:  # if NoseTackles > 0.5
#                                 if Age <= 25.5:
#                                   return [[4. 0.]]
#                                 else:  # if Age > 25.5
#                                   if S <= 4.460000038146973:
#                                     return [[1. 0.]]
#                                   else:  # if S > 4.460000038146973
#                                     return [[0. 5.]]
#                             else:  # if S > 5.820000171661377
#                               return [[2. 0.]]
#                       else:  # if TurfCode > 2.5
#                         return [[2. 0.]]
#                 else:  # if DefensiveEnds > 2.5
#                   if OffensiveGuards <= 2.5:
#                     return [[ 0. 30.]]
#                   else:  # if OffensiveGuards > 2.5
#                     if A <= 1.3499999642372131:
#                       return [[0. 3.]]
#                     else:  # if A > 1.3499999642372131
#                       return [[2. 0.]]
#               else:  # if Age > 35.0
#                 return [[3. 0.]]
#             else:  # if S > 7.109999895095825
#               return [[4. 0.]]
#       else:  # if A > 1.8550000190734863
#         if Down <= 1.5:
#           if A <= 2.2649999856948853:
#             if OffensiveGuards <= 1.5:
#               if DefensiveEnds <= 2.5:
#                 if Age <= 24.5:
#                   if isHomeTeam <= 0.5:
#                     return [[2. 0.]]
#                   else:  # if isHomeTeam > 0.5
#                     return [[0. 1.]]
#                 else:  # if Age > 24.5
#                   return [[ 0. 17.]]
#               else:  # if DefensiveEnds > 2.5
#                 return [[3. 0.]]
#             else:  # if OffensiveGuards > 1.5
#               if Age <= 26.5:
#                 if TimeSnapDiff <= 1.5:
#                   if A <= 2.240000009536743:
#                     if DefendersInTheBox <= 6.5:
#                       return [[2. 0.]]
#                     else:  # if DefendersInTheBox > 6.5
#                       if PlayerHeightInches <= 72.5:
#                         if IsPossTeamInLead <= 0.5:
#                           return [[4. 0.]]
#                         else:  # if IsPossTeamInLead > 0.5
#                           if DefensiveEnds <= 1.5:
#                             return [[2. 0.]]
#                           else:  # if DefensiveEnds > 1.5
#                             return [[0. 8.]]
#                       else:  # if PlayerHeightInches > 72.5
#                         return [[0. 8.]]
#                   else:  # if A > 2.240000009536743
#                     return [[3. 0.]]
#                 else:  # if TimeSnapDiff > 1.5
#                   return [[5. 0.]]
#               else:  # if Age > 26.5
#                 return [[6. 0.]]
#           else:  # if A > 2.2649999856948853
#             if PlayerHeightInches <= 70.5:
#               if S <= 4.024999976158142:
#                 if Safeties <= 1.5:
#                   return [[8. 0.]]
#                 else:  # if Safeties > 1.5
#                   if DefensiveTackles <= 1.5:
#                     return [[3. 0.]]
#                   else:  # if DefensiveTackles > 1.5
#                     if A <= 2.784999966621399:
#                       if Cornerbacks <= 2.5:
#                         return [[ 0. 13.]]
#                       else:  # if Cornerbacks > 2.5
#                         return [[1. 0.]]
#                     else:  # if A > 2.784999966621399
#                       return [[2. 0.]]
#               else:  # if S > 4.024999976158142
#                 if A <= 3.2899999618530273:
#                   if Season <= 2018.5:
#                     if DefensiveTackles <= 2.5:
#                       if NoseTackles <= 2.5:
#                         return [[ 0. 24.]]
#                       else:  # if NoseTackles > 2.5
#                         return [[1. 0.]]
#                     else:  # if DefensiveTackles > 2.5
#                       if PlayerHeightInches <= 68.5:
#                         return [[3. 0.]]
#                       else:  # if PlayerHeightInches > 68.5
#                         return [[0. 3.]]
#                   else:  # if Season > 2018.5
#                     if OffensiveGuards <= 1.5:
#                       if DefendersInTheBox <= 9.5:
#                         return [[1. 0.]]
#                       else:  # if DefendersInTheBox > 9.5
#                         return [[0. 6.]]
#                     else:  # if OffensiveGuards > 1.5
#                       return [[8. 0.]]
#                 else:  # if A > 3.2899999618530273
#                   if S <= 4.265000104904175:
#                     return [[1. 0.]]
#                   else:  # if S > 4.265000104904175
#                     return [[ 0. 25.]]
#             else:  # if PlayerHeightInches > 70.5
#               if NoseTackles <= 1.5:
#                 if S <= 3.834999918937683:
#                   if A <= 2.940000057220459:
#                     if S <= 3.0649999380111694:
#                       if TimeSnapDiff <= 1.5:
#                         return [[ 0. 12.]]
#                       else:  # if TimeSnapDiff > 1.5
#                         return [[1. 0.]]
#                     else:  # if S > 3.0649999380111694
#                       if LineBackers <= 4.5:
#                         return [[9. 0.]]
#                       else:  # if LineBackers > 4.5
#                         return [[0. 1.]]
#                   else:  # if A > 2.940000057220459
#                     if A <= 4.7149999141693115:
#                       if TurfCode <= 2.5:
#                         if Safeties <= 1.5:
#                           return [[1. 0.]]
#                         else:  # if Safeties > 1.5
#                           if OffensiveGuards <= 0.5:
#                             return [[1. 0.]]
#                           else:  # if OffensiveGuards > 0.5
#                             return [[ 0. 41.]]
#                       else:  # if TurfCode > 2.5
#                         return [[1. 0.]]
#                     else:  # if A > 4.7149999141693115
#                       return [[2. 0.]]
#                 else:  # if S > 3.834999918937683
#                   if S <= 5.5299999713897705:
#                     if TightEnds <= 3.5:
#                       if A <= 2.5999999046325684:
#                         return [[ 0. 36.]]
#                       else:  # if A > 2.5999999046325684
#                         if S <= 5.305000066757202:
#                           if A <= 2.6200000047683716:
#                             return [[1. 0.]]
#                           else:  # if A > 2.6200000047683716
#                             if Quarter <= 3.5:
#                               if LineBackers <= 2.5:
#                                 return [[ 0. 46.]]
#                               else:  # if LineBackers > 2.5
#                                 if Cornerbacks <= 3.5:
#                                   if DefensiveTackles <= 1.5:
#                                     return [[ 0. 39.]]
#                                   else:  # if DefensiveTackles > 1.5
#                                     if Age <= 30.0:
#                                       if NoseTackles <= 0.5:
#                                         if S <= 4.960000038146973:
#                                           if A <= 2.8600000143051147:
#                                             if StadiumTypeCode <= 1.5:
#                                               return [[1. 0.]]
#                                             else:  # if StadiumTypeCode > 1.5
#                                               return [[0. 2.]]
#                                           else:  # if A > 2.8600000143051147
#                                             return [[ 0. 16.]]
#                                         else:  # if S > 4.960000038146973
#                                           return [[1. 0.]]
#                                       else:  # if NoseTackles > 0.5
#                                         return [[ 0. 23.]]
#                                     else:  # if Age > 30.0
#                                       return [[1. 0.]]
#                                 else:  # if Cornerbacks > 3.5
#                                   return [[1. 0.]]
#                             else:  # if Quarter > 3.5
#                               if Age <= 26.5:
#                                 if Cornerbacks <= 3.5:
#                                   if Centers <= 0.5:
#                                     if OffensiveGuards <= 3.5:
#                                       return [[1. 0.]]
#                                     else:  # if OffensiveGuards > 3.5
#                                       return [[0. 2.]]
#                                   else:  # if Centers > 0.5
#                                     return [[ 0. 16.]]
#                                 else:  # if Cornerbacks > 3.5
#                                   return [[1. 0.]]
#                               else:  # if Age > 26.5
#                                 return [[2. 0.]]
#                         else:  # if S > 5.305000066757202
#                           return [[1. 0.]]
#                     else:  # if TightEnds > 3.5
#                       return [[1. 0.]]
#                   else:  # if S > 5.5299999713897705
#                     if PlayerHeightInches <= 74.0:
#                       return [[2. 0.]]
#                     else:  # if PlayerHeightInches > 74.0
#                       return [[0. 2.]]
#               else:  # if NoseTackles > 1.5
#                 if S <= 4.03000009059906:
#                   return [[0. 6.]]
#                 else:  # if S > 4.03000009059906
#                   if A <= 2.8700000047683716:
#                     return [[0. 1.]]
#                   else:  # if A > 2.8700000047683716
#                     return [[5. 0.]]
#         else:  # if Down > 1.5
#           if Distance <= 1.5:
#             if Season <= 2017.5:
#               if Cornerbacks <= 0.5:
#                 if NoseTackles <= 0.5:
#                   if Age <= 31.0:
#                     if isPlayDirectionLeft <= 0.5:
#                       if OffensiveGuards <= 1.5:
#                         return [[1. 0.]]
#                       else:  # if OffensiveGuards > 1.5
#                         if DefensiveTackles <= 4.5:
#                           return [[ 0. 11.]]
#                         else:  # if DefensiveTackles > 4.5
#                           return [[1. 0.]]
#                     else:  # if isPlayDirectionLeft > 0.5
#                       return [[ 0. 41.]]
#                   else:  # if Age > 31.0
#                     return [[1. 0.]]
#                 else:  # if NoseTackles > 0.5
#                   if NoseTackles <= 2.5:
#                     if DefendersInTheBox <= 9.5:
#                       return [[0. 1.]]
#                     else:  # if DefendersInTheBox > 9.5
#                       return [[7. 0.]]
#                   else:  # if NoseTackles > 2.5
#                     if A <= 2.440000057220459:
#                       return [[0. 3.]]
#                     else:  # if A > 2.440000057220459
#                       return [[1. 0.]]
#               else:  # if Cornerbacks > 0.5
#                 if Age <= 23.5:
#                   if PlayerHeightInches <= 72.5:
#                     if S <= 2.3100000619888306:
#                       return [[1. 0.]]
#                     else:  # if S > 2.3100000619888306
#                       if OffensiveGuards <= 1.5:
#                         return [[ 0. 65.]]
#                       else:  # if OffensiveGuards > 1.5
#                         if Cornerbacks <= 2.5:
#                           if A <= 3.740000009536743:
#                             if S <= 3.7300000190734863:
#                               return [[ 0. 67.]]
#                             else:  # if S > 3.7300000190734863
#                               if S <= 3.7450000047683716:
#                                 return [[1. 0.]]
#                               else:  # if S > 3.7450000047683716
#                                 if A <= 2.4250000715255737:
#                                   if StadiumTypeCode <= 3.0:
#                                     return [[ 0. 35.]]
#                                   else:  # if StadiumTypeCode > 3.0
#                                     if LineBackers <= 3.5:
#                                       return [[1. 0.]]
#                                     else:  # if LineBackers > 3.5
#                                       return [[0. 2.]]
#                                 else:  # if A > 2.4250000715255737
#                                   if DefensiveEnds <= 1.5:
#                                     if A <= 2.5549999475479126:
#                                       return [[1. 0.]]
#                                     else:  # if A > 2.5549999475479126
#                                       return [[ 0. 25.]]
#                                   else:  # if DefensiveEnds > 1.5
#                                     if S <= 4.264999866485596:
#                                       return [[3. 0.]]
#                                     else:  # if S > 4.264999866485596
#                                       if Centers <= 0.5:
#                                         return [[0. 8.]]
#                                       else:  # if Centers > 0.5
#                                         if Centers <= 1.5:
#                                           return [[3. 0.]]
#                                         else:  # if Centers > 1.5
#                                           return [[0. 2.]]
#                           else:  # if A > 3.740000009536743
#                             return [[2. 0.]]
#                         else:  # if Cornerbacks > 2.5
#                           if PlayerHeightInches <= 70.5:
#                             if A <= 2.4550000429153442:
#                               if S <= 3.6299999952316284:
#                                 return [[2. 0.]]
#                               else:  # if S > 3.6299999952316284
#                                 return [[0. 3.]]
#                             else:  # if A > 2.4550000429153442
#                               return [[ 0. 15.]]
#                           else:  # if PlayerHeightInches > 70.5
#                             return [[  0. 100.]]
#                   else:  # if PlayerHeightInches > 72.5
#                     return [[  0. 109.]]
#                 else:  # if Age > 23.5
#                   if A <= 1.9450000524520874:
#                     if LineBackers <= 3.5:
#                       if Quarter <= 2.5:
#                         if Quarter <= 1.5:
#                           return [[1. 0.]]
#                         else:  # if Quarter > 1.5
#                           return [[0. 4.]]
#                       else:  # if Quarter > 2.5
#                         return [[4. 0.]]
#                     else:  # if LineBackers > 3.5
#                       if Centers <= 0.5:
#                         if isPlayDirectionLeft <= 0.5:
#                           return [[1. 0.]]
#                         else:  # if isPlayDirectionLeft > 0.5
#                           return [[0. 1.]]
#                       else:  # if Centers > 0.5
#                         return [[ 0. 12.]]
#                   else:  # if A > 1.9450000524520874
#                     if S <= 4.940000057220459:
#                       if S <= 3.90500009059906:
#                         if S <= 3.8700000047683716:
#                           if S <= 3.7549999952316284:
#                             if Centers <= 2.5:
#                               if OffensiveGuards <= 0.5:
#                                 return [[1. 0.]]
#                               else:  # if OffensiveGuards > 0.5
#                                 if A <= 4.1600000858306885:
#                                   if TightEnds <= 2.5:
#                                     if DefensiveEnds <= 1.5:
#                                       if Age <= 33.0:
#                                         if PlayerHeightInches <= 74.5:
#                                           if A <= 2.65500009059906:
#                                             if S <= 3.715000033378601:
#                                               if Age <= 24.5:
#                                                 if IsPossTeamInLead <= 0.5:
#                                                   return [[1. 0.]]
#                                                 else:  # if IsPossTeamInLead > 0.5
#                                                   if S <= 3.2200000286102295:
#                                                     return [[ 0. 12.]]
#                                                   else:  # if S > 3.2200000286102295
#                                                     if LineBackers <= 2.5:
#                                                       return [[1. 0.]]
#                                                     else:  # if LineBackers > 2.5
#                                                       return [[0. 2.]]
#                                               else:  # if Age > 24.5
#                                                 return [[ 0. 57.]]
#                                             else:  # if S > 3.715000033378601
#                                               return [[1. 0.]]
#                                           else:  # if A > 2.65500009059906
#                                             return [[ 0. 83.]]
#                                         else:  # if PlayerHeightInches > 74.5
#                                           return [[1. 0.]]
#                                       else:  # if Age > 33.0
#                                         if S <= 3.1049998998641968:
#                                           return [[2. 0.]]
#                                         else:  # if S > 3.1049998998641968
#                                           return [[0. 3.]]
#                                     else:  # if DefensiveEnds > 1.5
#                                       if A <= 2.725000023841858:
#                                         if DefensiveTackles <= 2.5:
#                                           if A <= 2.1700000762939453:
#                                             if A <= 2.0749999284744263:
#                                               return [[ 0. 27.]]
#                                             else:  # if A > 2.0749999284744263
#                                               if A <= 2.1149998903274536:
#                                                 if PlayerHeightInches <= 69.5:
#                                                   return [[0. 4.]]
#                                                 else:  # if PlayerHeightInches > 69.5
#                                                   return [[4. 0.]]
#                                               else:  # if A > 2.1149998903274536
#                                                 if StadiumTypeCode <= 2.5:
#                                                   return [[ 0. 20.]]
#                                                 else:  # if StadiumTypeCode > 2.5
#                                                   return [[1. 0.]]
#                                           else:  # if A > 2.1700000762939453
#                                             if PlayerHeightInches <= 74.0:
#                                               return [[ 0. 75.]]
#                                             else:  # if PlayerHeightInches > 74.0
#                                               if IsPossTeamInLead <= 0.5:
#                                                 return [[1. 0.]]
#                                               else:  # if IsPossTeamInLead > 0.5
#                                                 return [[0. 7.]]
#                                         else:  # if DefensiveTackles > 2.5
#                                           return [[1. 0.]]
#                                       else:  # if A > 2.725000023841858
#                                         if IsPossTeamInLead <= 0.5:
#                                           if A <= 3.0049999952316284:
#                                             return [[4. 0.]]
#                                           else:  # if A > 3.0049999952316284
#                                             if TurfCode <= 1.5:
#                                               if OffensiveGuards <= 1.5:
#                                                 if Cornerbacks <= 2.5:
#                                                   return [[0. 2.]]
#                                                 else:  # if Cornerbacks > 2.5
#                                                   return [[1. 0.]]
#                                               else:  # if OffensiveGuards > 1.5
#                                                 return [[2. 0.]]
#                                             else:  # if TurfCode > 1.5
#                                               return [[0. 6.]]
#                                         else:  # if IsPossTeamInLead > 0.5
#                                           return [[ 0. 13.]]
#                                   else:  # if TightEnds > 2.5
#                                     return [[ 0. 34.]]
#                                 else:  # if A > 4.1600000858306885
#                                   return [[1. 0.]]
#                             else:  # if Centers > 2.5
#                               return [[1. 0.]]
#                           else:  # if S > 3.7549999952316284
#                             return [[ 0. 56.]]
#                         else:  # if S > 3.8700000047683716
#                           if Age <= 27.5:
#                             return [[5. 0.]]
#                           else:  # if Age > 27.5
#                             return [[0. 1.]]
#                       else:  # if S > 3.90500009059906
#                         if A <= 2.819999933242798:
#                           if A <= 2.784999966621399:
#                             if LineBackers <= 4.5:
#                               if TimeSnapDiff <= 1.5:
#                                 return [[ 0. 99.]]
#                               else:  # if TimeSnapDiff > 1.5
#                                 if PlayerHeightInches <= 70.5:
#                                   return [[ 0. 20.]]
#                                 else:  # if PlayerHeightInches > 70.5
#                                   if IsPossTeamInLead <= 0.5:
#                                     if TurfCode <= 2.5:
#                                       return [[ 0. 13.]]
#                                     else:  # if TurfCode > 2.5
#                                       return [[1. 0.]]
#                                   else:  # if IsPossTeamInLead > 0.5
#                                     if DefensiveEnds <= 3.0:
#                                       return [[3. 0.]]
#                                     else:  # if DefensiveEnds > 3.0
#                                       return [[0. 1.]]
#                             else:  # if LineBackers > 4.5
#                               return [[1. 0.]]
#                           else:  # if A > 2.784999966621399
#                             return [[2. 0.]]
#                         else:  # if A > 2.819999933242798
#                           if PlayerHeightInches <= 72.5:
#                             return [[  0. 152.]]
#                           else:  # if PlayerHeightInches > 72.5
#                             if Quarter <= 2.5:
#                               return [[ 0. 16.]]
#                             else:  # if Quarter > 2.5
#                               if Down <= 2.5:
#                                 return [[0. 2.]]
#                               else:  # if Down > 2.5
#                                 return [[1. 0.]]
#                     else:  # if S > 4.940000057220459
#                       if S <= 5.7200000286102295:
#                         if DefensiveTackles <= 1.5:
#                           return [[6. 0.]]
#                         else:  # if DefensiveTackles > 1.5
#                           if TimeSnapDiff <= 1.5:
#                             if PlayerHeightInches <= 68.5:
#                               if S <= 5.109999895095825:
#                                 if IsPossTeamInLead <= 0.5:
#                                   if Down <= 2.5:
#                                     return [[1. 0.]]
#                                   else:  # if Down > 2.5
#                                     return [[0. 3.]]
#                                 else:  # if IsPossTeamInLead > 0.5
#                                   return [[0. 3.]]
#                               else:  # if S > 5.109999895095825
#                                 return [[3. 0.]]
#                             else:  # if PlayerHeightInches > 68.5
#                               if A <= 4.234999895095825:
#                                 return [[ 0. 14.]]
#                               else:  # if A > 4.234999895095825
#                                 return [[1. 0.]]
#                           else:  # if TimeSnapDiff > 1.5
#                             return [[ 0. 22.]]
#                       else:  # if S > 5.7200000286102295
#                         return [[ 0. 21.]]
#             else:  # if Season > 2017.5
#               if Down <= 3.5:
#                 if A <= 3.9800000190734863:
#                   if S <= 4.565000057220459:
#                     if A <= 2.8850001096725464:
#                       if S <= 3.75:
#                         if IsPossTeamInLead <= 0.5:
#                           if StadiumTypeCode <= 1.5:
#                             if LineBackers <= 1.5:
#                               return [[2. 0.]]
#                             else:  # if LineBackers > 1.5
#                               if A <= 2.524999976158142:
#                                 return [[ 0. 17.]]
#                               else:  # if A > 2.524999976158142
#                                 if S <= 3.6100000143051147:
#                                   if TightEnds <= 1.5:
#                                     if Quarter <= 2.5:
#                                       if TimeSnapDiff <= 1.5:
#                                         return [[ 0. 11.]]
#                                       else:  # if TimeSnapDiff > 1.5
#                                         return [[1. 0.]]
#                                     else:  # if Quarter > 2.5
#                                       if isHomeTeam <= 0.5:
#                                         return [[0. 1.]]
# ...
#                                             return [[0. 2.]]
#                                     else:  # if Safeties > 2.5
#                                       if PlayerHeightInches <= 70.5:
#                                         return [[6. 0.]]
#                                       else:  # if PlayerHeightInches > 70.5
#                                         if A <= 3.125:
#                                           return [[3. 0.]]
#                                         else:  # if A > 3.125
#                                           if TimeSnapDiff <= 1.5:
#                                             return [[0. 8.]]
#                                           else:  # if TimeSnapDiff > 1.5
#                                             if A <= 3.424999952316284:
#                                               return [[2. 0.]]
#                                             else:  # if A > 3.424999952316284
#                                               return [[0. 3.]]
#                                   else:  # if S > 6.840000152587891
#                                     return [[0. 3.]]
#                               else:  # if DefensiveTackles > 2.5
#                                 return [[12.  0.]]
#                             else:  # if NoseTackles > 0.5
#                               if LineBackers <= 5.5:
#                                 if A <= 2.915000081062317:
#                                   if DefendersInTheBox <= 5.5:
#                                     return [[0. 1.]]
#                                   else:  # if DefendersInTheBox > 5.5
#                                     return [[1. 0.]]
#                                 else:  # if A > 2.915000081062317
#                                   return [[56.  0.]]
#                               else:  # if LineBackers > 5.5
#                                 return [[0. 5.]]
#                         else:  # if Down > 2.5
#                           return [[8. 0.]]
#                   else:  # if NoseTackles > 1.5
#                     return [[18.  0.]]
#               else:  # if A > 3.584999918937683
#                 if S <= 4.924999952316284:
#                   if S <= 4.7850000858306885:
#                     if Cornerbacks <= 2.5:
#                       if NoseTackles <= 0.5:
#                         if A <= 4.1000001430511475:
#                           if Quarter <= 2.5:
#                             if Age <= 22.5:
#                               return [[2. 0.]]
#                             else:  # if Age > 22.5
#                               if TimeSnapDiff <= 1.5:
#                                 return [[ 0. 13.]]
#                               else:  # if TimeSnapDiff > 1.5
#                                 if Quarter <= 1.5:
#                                   return [[2. 0.]]
#                                 else:  # if Quarter > 1.5
#                                   if Down <= 1.5:
#                                     return [[0. 5.]]
#                                   else:  # if Down > 1.5
#                                     return [[1. 0.]]
#                           else:  # if Quarter > 2.5
#                             return [[9. 0.]]
#                         else:  # if A > 4.1000001430511475
#                           if DefensiveTackles <= 3.5:
#                             return [[16.  0.]]
#                           else:  # if DefensiveTackles > 3.5
#                             return [[0. 2.]]
#                       else:  # if NoseTackles > 0.5
#                         return [[16.  0.]]
#                     else:  # if Cornerbacks > 2.5
#                       if Quarter <= 3.5:
#                         if A <= 3.7050000429153442:
#                           return [[8. 0.]]
#                         else:  # if A > 3.7050000429153442
#                           if A <= 3.819999933242798:
#                             if S <= 4.729999780654907:
#                               return [[ 0. 20.]]
#                             else:  # if S > 4.729999780654907
#                               return [[3. 0.]]
#                           else:  # if A > 3.819999933242798
#                             if Age <= 24.5:
#                               if DefensiveEnds <= 2.5:
#                                 if Distance <= 7.5:
#                                   return [[0. 6.]]
#                                 else:  # if Distance > 7.5
#                                   if A <= 4.129999876022339:
#                                     return [[6. 0.]]
#                                   else:  # if A > 4.129999876022339
#                                     if Quarter <= 1.5:
#                                       return [[3. 0.]]
#                                     else:  # if Quarter > 1.5
#                                       if OffensiveGuards <= 1.5:
#                                         return [[3. 0.]]
#                                       else:  # if OffensiveGuards > 1.5
#                                         return [[ 0. 14.]]
#                               else:  # if DefensiveEnds > 2.5
#                                 return [[6. 0.]]
#                             else:  # if Age > 24.5
#                               return [[10.  0.]]
#                       else:  # if Quarter > 3.5
#                         if DefendersInTheBox <= 6.5:
#                           return [[ 0. 12.]]
#                         else:  # if DefendersInTheBox > 6.5
#                           if isHomeTeam <= 0.5:
#                             return [[2. 0.]]
#                           else:  # if isHomeTeam > 0.5
#                             return [[0. 3.]]
#                   else:  # if S > 4.7850000858306885
#                     if Season <= 2018.5:
#                       if NoseTackles <= 0.5:
#                         if DefensiveEnds <= 0.5:
#                           if PlayerHeightInches <= 70.5:
#                             return [[1. 0.]]
#                           else:  # if PlayerHeightInches > 70.5
#                             return [[0. 2.]]
#                         else:  # if DefensiveEnds > 0.5
#                           return [[19.  0.]]
#                       else:  # if NoseTackles > 0.5
#                         if A <= 3.899999976158142:
#                           return [[4. 0.]]
#                         else:  # if A > 3.899999976158142
#                           if Quarter <= 3.5:
#                             return [[ 0. 10.]]
#                           else:  # if Quarter > 3.5
#                             return [[1. 0.]]
#                     else:  # if Season > 2018.5
#                       return [[20.  0.]]
#                 else:  # if S > 4.924999952316284
#                   if DistanceBins <= 2.5:
#                     if PlayerHeightInches <= 70.5:
#                       if S <= 4.944999933242798:
#                         if DefendersInTheBox <= 5.5:
#                           return [[1. 0.]]
#                         else:  # if DefendersInTheBox > 5.5
#                           if A <= 3.725000023841858:
#                             return [[1. 0.]]
#                           else:  # if A > 3.725000023841858
#                             return [[ 0. 10.]]
#                       else:  # if S > 4.944999933242798
#                         if DefensiveTackles <= 1.5:
#                           if S <= 5.005000114440918:
#                             if LineBackers <= 3.5:
#                               return [[5. 0.]]
#                             else:  # if LineBackers > 3.5
#                               if DefensiveTackles <= 0.5:
#                                 return [[1. 0.]]
#                               else:  # if DefensiveTackles > 0.5
#                                 return [[0. 3.]]
#                           else:  # if S > 5.005000114440918
#                             return [[21.  0.]]
#                         else:  # if DefensiveTackles > 1.5
#                           if LineBackers <= 3.5:
#                             if S <= 5.56000018119812:
#                               if S <= 5.169999837875366:
#                                 if DefensiveTackles <= 3.5:
#                                   if OffensiveGuards <= 2.5:
#                                     return [[10.  0.]]
#                                   else:  # if OffensiveGuards > 2.5
#                                     if PlayerHeightInches <= 69.5:
#                                       return [[0. 2.]]
#                                     else:  # if PlayerHeightInches > 69.5
#                                       return [[1. 0.]]
#                                 else:  # if DefensiveTackles > 3.5
#                                   return [[0. 3.]]
#                               else:  # if S > 5.169999837875366
#                                 if TightEnds <= 1.5:
#                                   return [[0. 9.]]
#                                 else:  # if TightEnds > 1.5
#                                   if A <= 3.7100000381469727:
#                                     return [[0. 5.]]
#                                   else:  # if A > 3.7100000381469727
#                                     return [[3. 0.]]
#                             else:  # if S > 5.56000018119812
#                               return [[4. 0.]]
#                           else:  # if LineBackers > 3.5
#                             return [[8. 0.]]
#                     else:  # if PlayerHeightInches > 70.5
#                       if S <= 5.025000095367432:
#                         if Quarter <= 2.5:
#                           if Season <= 2018.5:
#                             if Down <= 1.5:
#                               return [[0. 9.]]
#                             else:  # if Down > 1.5
#                               return [[2. 0.]]
#                           else:  # if Season > 2018.5
#                             return [[4. 0.]]
#                         else:  # if Quarter > 2.5
#                           if Centers <= 2.5:
#                             return [[ 0. 23.]]
#                           else:  # if Centers > 2.5
#                             return [[1. 0.]]
#                       else:  # if S > 5.025000095367432
#                         if S <= 5.0950000286102295:
#                           return [[13.  0.]]
#                         else:  # if S > 5.0950000286102295
#                           if A <= 3.6049998998641968:
#                             return [[0. 9.]]
#                           else:  # if A > 3.6049998998641968
#                             if Down <= 1.5:
#                               if A <= 3.975000023841858:
#                                 if TightEnds <= 1.5:
#                                   if Centers <= 1.5:
#                                     if S <= 5.365000009536743:
#                                       if PlayerHeightInches <= 72.5:
#                                         return [[0. 7.]]
#                                       else:  # if PlayerHeightInches > 72.5
#                                         return [[1. 0.]]
#                                     else:  # if S > 5.365000009536743
#                                       return [[7. 0.]]
#                                   else:  # if Centers > 1.5
#                                     if Age <= 22.5:
#                                       if IsPossTeamInLead <= 0.5:
#                                         return [[0. 3.]]
#                                       else:  # if IsPossTeamInLead > 0.5
#                                         return [[2. 0.]]
#                                     else:  # if Age > 22.5
#                                       return [[ 0. 17.]]
#                                 else:  # if TightEnds > 1.5
#                                   return [[6. 0.]]
#                               else:  # if A > 3.975000023841858
#                                 if DefensiveTackles <= 1.5:
#                                   return [[14.  0.]]
#                                 else:  # if DefensiveTackles > 1.5
#                                   if A <= 4.384999990463257:
#                                     return [[8. 0.]]
#                                   else:  # if A > 4.384999990463257
#                                     if Age <= 23.5:
#                                       return [[3. 0.]]
#                                     else:  # if Age > 23.5
#                                       if DefendersInTheBox <= 6.5:
#                                         if Quarter <= 3.5:
#                                           return [[2. 0.]]
#                                         else:  # if Quarter > 3.5
#                                           return [[0. 3.]]
#                                       else:  # if DefendersInTheBox > 6.5
#                                         return [[0. 8.]]
#                             else:  # if Down > 1.5
#                               if isHomeTeam <= 0.5:
#                                 if A <= 3.8249999284744263:
#                                   if StadiumTypeCode <= 2.0:
#                                     return [[0. 6.]]
#                                   else:  # if StadiumTypeCode > 2.0
#                                     return [[1. 0.]]
#                                 else:  # if A > 3.8249999284744263
#                                   return [[5. 0.]]
#                               else:  # if isHomeTeam > 0.5
#                                 if StadiumTypeCode <= 3.5:
#                                   if Safeties <= 2.5:
#                                     return [[ 0. 22.]]
#                                   else:  # if Safeties > 2.5
#                                     if TurfCode <= 1.5:
#                                       return [[1. 0.]]
#                                     else:  # if TurfCode > 1.5
#                                       return [[0. 1.]]
#                                 else:  # if StadiumTypeCode > 3.5
#                                   return [[1. 0.]]
#                   else:  # if DistanceBins > 2.5
#                     return [[0. 7.]]
#         else:  # if Distance > 11.5
#           if DefensiveTackles <= 2.5:
#             if isPlayDirectionLeft <= 0.5:
#               if A <= 4.575000047683716:
#                 return [[100.   0.]]
#               else:  # if A > 4.575000047683716
#                 if TimeSnapDiff <= 1.5:
#                   return [[7. 0.]]
#                 else:  # if TimeSnapDiff > 1.5
#                   if S <= 1.7699999809265137:
#                     return [[1. 0.]]
#                   else:  # if S > 1.7699999809265137
#                     return [[0. 2.]]
#             else:  # if isPlayDirectionLeft > 0.5
#               if PlayerHeightInches <= 71.5:
#                 if S <= 3.965000033378601:
#                   if A <= 3.2050000429153442:
#                     if S <= 3.625:
#                       return [[3. 0.]]
#                     else:  # if S > 3.625
#                       return [[0. 9.]]
#                   else:  # if A > 3.2050000429153442
#                     if DefendersInTheBox <= 6.5:
#                       return [[22.  0.]]
#                     else:  # if DefendersInTheBox > 6.5
#                       if TimeSnapDiff <= 1.5:
#                         return [[0. 4.]]
#                       else:  # if TimeSnapDiff > 1.5
#                         return [[1. 0.]]
#                 else:  # if S > 3.965000033378601
#                   if S <= 5.695000171661377:
#                     if Distance <= 18.5:
#                       return [[41.  0.]]
#                     else:  # if Distance > 18.5
#                       if Quarter <= 3.5:
#                         return [[6. 0.]]
#                       else:  # if Quarter > 3.5
#                         return [[0. 2.]]
#                   else:  # if S > 5.695000171661377
#                     return [[0. 2.]]
#               else:  # if PlayerHeightInches > 71.5
#                 return [[35.  0.]]
#           else:  # if DefensiveTackles > 2.5
#             if TimeSnapDiff <= 1.5:
#               return [[5. 0.]]
#             else:  # if TimeSnapDiff > 1.5
#               if TightEnds <= 1.5:
#                 return [[0. 8.]]
#               else:  # if TightEnds > 1.5
#                 return [[1. 0.]]

# %%
# The score method returns the accuracy of the model
score = dtree.score(X_test, y_test)
print(score)
# Out:
# 0.8744082840236687

# %%
# List of values to try for max_depth:
max_depth_range = list(range(1, numDimensions + 1))# List to store the average RMSE for each value of max_depth:
accuracy = []
for depth in max_depth_range:
    
    clf = DecisionTreeClassifier(max_depth = depth, random_state = 0)
    clf.fit(X_train, y_train)    
    score = clf.score(X_test, y_test)
    accuracy.append(score)
    
pd.DataFrame(accuracy)
# Out:
#            0
# 0   0.721746
# 1   0.721746
# 2   0.723669
# 3   0.730695
# 4   0.734320
# 5   0.736317
# 6   0.743861
# 7   0.746302
# 8   0.749630
# 9   0.759689
# 10  0.770562
# 11  0.779882
# 12  0.794305
# 13  0.807544
# 14  0.815976
# 15  0.823003
# 16  0.836538
# 17  0.845192
# 18  0.852663
# 19  0.865237
# 20  0.868417
# 21  0.872411
# 22  0.875740
# 23  0.877145
# 24  0.878328

# %%
importances = pd.DataFrame({'feature':X_train.columns,'importance':np.round(clf.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False)
importances
# Out:
#                 feature  importance
# 17             Distance       0.249
# 16                    A       0.148
# 7                     S       0.134
# 9                   Age       0.053
# 5    PlayerHeightInches       0.044
# 13              Quarter       0.032
# 19          LineBackers       0.029
# 20    DefendersInTheBox       0.029
# 3         DefensiveEnds       0.025
# 14     DefensiveTackles       0.024
# 15      OffensiveGuards       0.023
# 10            TightEnds       0.021
# 21               Season       0.020
# 22             Safeties       0.018
# 18      StadiumTypeCode       0.017
# 1               Centers       0.017
# 0           Cornerbacks       0.017
# 12  isPlayDirectionLeft       0.016
# 8                  Down       0.015
# 6              TurfCode       0.014
# 4           NoseTackles       0.014
# 2            isHomeTeam       0.014
# 11     IsPossTeamInLead       0.013
# 24         TimeSnapDiff       0.013
# 23         DistanceBins       0.002
