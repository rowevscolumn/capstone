# %% [markdown]
# # Decision Tree - Oversampling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier #Import scikit-Tree For Decision Tree
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import classification_report,confusion_matrix #import Confusion Matrix
from sklearn.model_selection import train_test_split # Splitting the data
from sklearn import preprocessing # Normalizing

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import time
# Out:
# D:\Users\sourc\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
df_o = pd.read_csv("../data/processed/data_oversampled.csv",index_col=0)

# %%
# Normalizing the data
x = df_o.values #returns a numpy array
col = df_o.columns
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_n = pd.DataFrame(x_scaled, columns = col)

# df_n

# %%
X = df_o.drop("isFirstDown",1)   #Feature Matrix
y = df_o["isFirstDown"]          #Target Variable

# %%
# from sklearn.model_selection import train_test_split # Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=72)

numDimensions = X_test.shape[1]

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (31544, 27)
# (13520, 27)
# (31544,)
# (13520,)

# %%
# Create Decision Tree classifer object
dtree = DecisionTreeClassifier(criterion="entropy")

# %%
# Train Decision Tree Classifer
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#Predict the response for test dataset
y_pred = dtree.predict(X_test)

# %%
accText = 'Decision Tree, Oversampled'

# %%
# Model Accuracy, how often is the classifier correct?

# accuracy: (tp + tn) / (p + n)
accuracy = (accuracy_score(y_test, y_pred)).astype('float64')
print('{:>10}: {:0.2%}'.format('Accuracy',accuracy))
# precision tp / (tp + fp)
precision = (precision_score(y_test, y_pred)).astype('float64')
print('{:>10}: {:0.2%}'.format('Precision',precision))
# recall: tp / (tp + fn)
recall = (recall_score(y_test, y_pred)).astype('float64')
print('{:>10}: {:0.2%}'.format('Recall',recall))
# f1: 2 tp / (2 tp + fp + fn)
f1 = (f1_score(y_test, y_pred)).astype('float64')
print('{:>10}: {:0.2%}'.format('F1 score',f1))
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = (auc(false_positive_rate, true_positive_rate)).astype('float64')
print('{:>10}: {:0.2%}'.format('ROC score',roc_auc))

acc = pd.read_csv("../data/external/accuracies.csv", index_col=0)
acc.at[accText, 'Accuracy'] = (accuracy)
acc.at[accText, 'Precision'] = (precision)
acc.at[accText, 'Recall'] = (recall)
acc.at[accText, 'F1'] = (f1)
acc.at[accText, 'ROC'] = (roc_auc)
acc.to_csv("../data/external/accuracies.csv")
# Out:
#   Accuracy: 87.99%
#  Precision: 82.99%
#     Recall: 95.85%
#   F1 score: 88.96%
#  ROC score: 87.91%

# %%
#Present Confusion Matrix to show accuracy
print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred, labels=[1,0]))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#
# [[6542  283]
#  [1341 5354]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87      6695
#            1       0.83      0.96      0.89      6825
#
#     accuracy                           0.88     13520
#    macro avg       0.89      0.88      0.88     13520
# weighted avg       0.89      0.88      0.88     13520

# %%
features = list(X)
#features

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True,rotate=True, max_depth=3)

import pydot
graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png(), width=7860, height=2160)

# %%
from sklearn.tree import _tree

def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [ \
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!" \
        for i in tree_.feature \
    ]
    print("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "  " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            print("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print("{}return {}".format(indent, tree_.value[node]))

    recurse(0, 1)
    
tree_to_code(dtree, features)
# Out:
# def tree(TightEnds, DefendersInTheBox, LineBackers, PlayerHeightInches, IsPossTeamInLead, TurfCode, StadiumTypeCode, DefensiveTackles, Safeties, Y, A, isPlayDirectionLeft, NoseTackles, Quarter, Centers, HomeScoreBeforePlay, OffensiveGuards, Season, Age, TimeSnapDiff, isHomeTeam, Distance, DefensiveEnds, S, Down, Cornerbacks, YardsToTouchdown):
#   if Distance <= 5.5:
#     if Distance <= 2.5:
#       if A <= 1.8550000190734863:
#         if S <= 4.120000123977661:
#           if A <= 1.5149999856948853:
#             if Distance <= 1.5:
#               if Y <= 22.445000648498535:
#                 return [[9. 0.]]
#               else:  # if Y > 22.445000648498535
#                 if Season <= 2017.5:
#                   if HomeScoreBeforePlay <= 32.0:
#                     if NoseTackles <= 0.5:
#                       if HomeScoreBeforePlay <= 18.5:
#                         if Y <= 30.914999961853027:
#                           if isPlayDirectionLeft <= 0.5:
#                             if HomeScoreBeforePlay <= 16.5:
#                               if A <= 0.5649999976158142:
#                                 if A <= 0.35999999940395355:
#                                   return [[3. 0.]]
#                                 else:  # if A > 0.35999999940395355
#                                   return [[0. 1.]]
#                               else:  # if A > 0.5649999976158142
#                                 return [[18.  0.]]
#                             else:  # if HomeScoreBeforePlay > 16.5
#                               return [[0. 2.]]
#                           else:  # if isPlayDirectionLeft > 0.5
#                             if LineBackers <= 2.5:
#                               return [[5. 0.]]
#                             else:  # if LineBackers > 2.5
#                               if Centers <= 1.5:
#                                 if PlayerHeightInches <= 70.5:
#                                   return [[ 0. 11.]]
#                                 else:  # if PlayerHeightInches > 70.5
#                                   if S <= 3.259999990463257:
#                                     if Age <= 26.0:
#                                       if PlayerHeightInches <= 71.5:
#                                         return [[1. 0.]]
#                                       else:  # if PlayerHeightInches > 71.5
#                                         return [[ 0. 10.]]
#                                     else:  # if Age > 26.0
#                                       return [[2. 0.]]
#                                   else:  # if S > 3.259999990463257
#                                     return [[3. 0.]]
#                               else:  # if Centers > 1.5
#                                 return [[4. 0.]]
#                         else:  # if Y > 30.914999961853027
#                           if A <= 1.2300000190734863:
#                             return [[2. 0.]]
#                           else:  # if A > 1.2300000190734863
#                             return [[ 0. 15.]]
#                       else:  # if HomeScoreBeforePlay > 18.5
#                         return [[10.  0.]]
#                     else:  # if NoseTackles > 0.5
#                       if DefendersInTheBox <= 8.5:
#                         if YardsToTouchdown <= 55.0:
#                           if Y <= 24.755000114440918:
#                             if S <= 3.1999999284744263:
#                               return [[3. 0.]]
#                             else:  # if S > 3.1999999284744263
#                               return [[0. 8.]]
#                           else:  # if Y > 24.755000114440918
#                             return [[ 0. 27.]]
#                         else:  # if YardsToTouchdown > 55.0
#                           if HomeScoreBeforePlay <= 10.0:
#                             if DefensiveEnds <= 0.5:
#                               return [[1. 0.]]
#                             else:  # if DefensiveEnds > 0.5
#                               return [[0. 2.]]
#                           else:  # if HomeScoreBeforePlay > 10.0
#                             return [[3. 0.]]
#                       else:  # if DefendersInTheBox > 8.5
#                         if HomeScoreBeforePlay <= 18.0:
#                           return [[6. 0.]]
#                         else:  # if HomeScoreBeforePlay > 18.0
#                           if A <= 1.2350000143051147:
#                             return [[1. 0.]]
#                           else:  # if A > 1.2350000143051147
#                             return [[0. 2.]]
#                   else:  # if HomeScoreBeforePlay > 32.0
#                     return [[ 0. 11.]]
#                 else:  # if Season > 2017.5
#                   if S <= 4.075000047683716:
#                     if A <= 0.949999988079071:
#                       return [[ 0. 27.]]
#                     else:  # if A > 0.949999988079071
#                       if A <= 1.0299999713897705:
#                         return [[5. 0.]]
#                       else:  # if A > 1.0299999713897705
#                         if YardsToTouchdown <= 40.0:
#                           if isPlayDirectionLeft <= 0.5:
#                             return [[3. 0.]]
#                           else:  # if isPlayDirectionLeft > 0.5
#                             if Age <= 23.5:
#                               return [[1. 0.]]
#                             else:  # if Age > 23.5
#                               return [[0. 8.]]
#                         else:  # if YardsToTouchdown > 40.0
#                           return [[ 0. 24.]]
#                   else:  # if S > 4.075000047683716
#                     return [[3. 0.]]
#             else:  # if Distance > 1.5
#               if isPlayDirectionLeft <= 0.5:
#                 return [[16.  0.]]
#               else:  # if isPlayDirectionLeft > 0.5
#                 if A <= 0.7249999940395355:
#                   if TimeSnapDiff <= 1.5:
#                     return [[2. 0.]]
#                   else:  # if TimeSnapDiff > 1.5
#                     return [[0. 6.]]
#                 else:  # if A > 0.7249999940395355
#                   if DefendersInTheBox <= 6.5:
#                     if Age <= 22.5:
#                       return [[1. 0.]]
#                     else:  # if Age > 22.5
#                       return [[0. 3.]]
#                   else:  # if DefendersInTheBox > 6.5
#                     if Centers <= 0.5:
#                       if Down <= 2.0:
#                         return [[0. 1.]]
#                       else:  # if Down > 2.0
#                         return [[1. 0.]]
#                     else:  # if Centers > 0.5
#                       return [[14.  0.]]
#           else:  # if A > 1.5149999856948853
#             if Y <= 29.949999809265137:
#               if A <= 1.8350000381469727:
#                 if Y <= 28.880000114440918:
#                   if DefensiveTackles <= 3.5:
#                     if YardsToTouchdown <= 63.0:
#                       if OffensiveGuards <= 3.5:
#                         if PlayerHeightInches <= 74.5:
#                           if NoseTackles <= 0.5:
#                             if TurfCode <= 1.5:
#                               return [[ 0. 42.]]
#                             else:  # if TurfCode > 1.5
#                               if YardsToTouchdown <= 1.5:
#                                 return [[3. 0.]]
#                               else:  # if YardsToTouchdown > 1.5
#                                 if Y <= 22.1899995803833:
#                                   return [[1. 0.]]
#                                 else:  # if Y > 22.1899995803833
#                                   if A <= 1.590000033378601:
#                                     if Quarter <= 3.0:
#                                       return [[1. 0.]]
#                                     else:  # if Quarter > 3.0
#                                       return [[0. 3.]]
#                                   else:  # if A > 1.590000033378601
#                                     return [[ 0. 27.]]
#                           else:  # if NoseTackles > 0.5
#                             if TightEnds <= 2.5:
#                               if PlayerHeightInches <= 70.5:
#                                 if S <= 2.5350000858306885:
#                                   return [[1. 0.]]
#                                 else:  # if S > 2.5350000858306885
#                                   return [[ 0. 19.]]
#                               else:  # if PlayerHeightInches > 70.5
#                                 if A <= 1.8250000476837158:
#                                   if S <= 2.3600000143051147:
#                                     return [[0. 1.]]
#                                   else:  # if S > 2.3600000143051147
#                                     return [[5. 0.]]
#                                 else:  # if A > 1.8250000476837158
#                                   return [[0. 5.]]
#                             else:  # if TightEnds > 2.5
#                               return [[3. 0.]]
#                         else:  # if PlayerHeightInches > 74.5
#                           if S <= 3.540000081062317:
#                             return [[3. 0.]]
#                           else:  # if S > 3.540000081062317
#                             return [[0. 1.]]
#                       else:  # if OffensiveGuards > 3.5
#                         return [[2. 0.]]
#                     else:  # if YardsToTouchdown > 63.0
#                       if Y <= 27.119999885559082:
#                         if Y <= 24.329999923706055:
#                           if Distance <= 1.5:
#                             return [[0. 1.]]
#                           else:  # if Distance > 1.5
#                             return [[6. 0.]]
#                         else:  # if Y > 24.329999923706055
#                           return [[ 0. 17.]]
#                       else:  # if Y > 27.119999885559082
#                         return [[6. 0.]]
#                   else:  # if DefensiveTackles > 3.5
#                     return [[3. 0.]]
#                 else:  # if Y > 28.880000114440918
#                   if LineBackers <= 2.5:
#                     if PlayerHeightInches <= 72.5:
#                       return [[0. 9.]]
#                     else:  # if PlayerHeightInches > 72.5
#                       return [[1. 0.]]
#                   else:  # if LineBackers > 2.5
#                     if S <= 3.5299999713897705:
#                       return [[11.  0.]]
#                     else:  # if S > 3.5299999713897705
#                       if HomeScoreBeforePlay <= 13.5:
#                         return [[0. 2.]]
#                       else:  # if HomeScoreBeforePlay > 13.5
#                         return [[2. 0.]]
#               else:  # if A > 1.8350000381469727
#                 return [[4. 0.]]
#             else:  # if Y > 29.949999809265137
#               if Y <= 30.15999984741211:
#                 return [[ 0. 23.]]
#               else:  # if Y > 30.15999984741211
#                 if A <= 1.6749999523162842:
#                   if Age <= 26.5:
#                     return [[ 0. 27.]]
#                   else:  # if Age > 26.5
#                     if A <= 1.6050000190734863:
#                       return [[0. 5.]]
#                     else:  # if A > 1.6050000190734863
#                       return [[2. 0.]]
#                 else:  # if A > 1.6749999523162842
#                   if S <= 2.9399999380111694:
#                     if TightEnds <= 1.5:
#                       return [[ 0. 12.]]
#                     else:  # if TightEnds > 1.5
#                       return [[1. 0.]]
#                   else:  # if S > 2.9399999380111694
#                     if Safeties <= 2.5:
#                       return [[6. 0.]]
#                     else:  # if Safeties > 2.5
#                       if Y <= 30.289999961853027:
#                         return [[1. 0.]]
#                       else:  # if Y > 30.289999961853027
#                         return [[0. 4.]]
#         else:  # if S > 4.120000123977661
#           if Y <= 33.77499961853027:
#             if DefendersInTheBox <= 7.5:
#               if YardsToTouchdown <= 13.0:
#                 if Down <= 2.5:
#                   if TightEnds <= 1.5:
#                     if HomeScoreBeforePlay <= 3.5:
#                       if isPlayDirectionLeft <= 0.5:
#                         return [[0. 3.]]
#                       else:  # if isPlayDirectionLeft > 0.5
#                         return [[1. 0.]]
#                     else:  # if HomeScoreBeforePlay > 3.5
#                       return [[ 0. 21.]]
#                   else:  # if TightEnds > 1.5
#                     if YardsToTouchdown <= 9.5:
#                       return [[2. 0.]]
#                     else:  # if YardsToTouchdown > 9.5
#                       return [[0. 1.]]
#                 else:  # if Down > 2.5
#                   if Y <= 30.274999618530273:
#                     return [[5. 0.]]
#                   else:  # if Y > 30.274999618530273
#                     return [[0. 2.]]
#               else:  # if YardsToTouchdown > 13.0
#                 if Safeties <= 2.5:
#                   if A <= 1.1950000524520874:
#                     if A <= 1.1349999904632568:
#                       if LineBackers <= 2.5:
#                         return [[ 0. 20.]]
#                       else:  # if LineBackers > 2.5
#                         if Y <= 31.78999900817871:
#                           if IsPossTeamInLead <= 0.5:
#                             if A <= 1.0299999713897705:
#                               if NoseTackles <= 0.5:
#                                 if S <= 5.069999933242798:
#                                   if YardsToTouchdown <= 61.5:
#                                     return [[2. 0.]]
#                                   else:  # if YardsToTouchdown > 61.5
#                                     return [[0. 3.]]
#                                 else:  # if S > 5.069999933242798
#                                   return [[0. 8.]]
#                               else:  # if NoseTackles > 0.5
#                                 return [[3. 0.]]
#                             else:  # if A > 1.0299999713897705
#                               return [[0. 9.]]
#                           else:  # if IsPossTeamInLead > 0.5
#                             return [[ 0. 19.]]
#                         else:  # if Y > 31.78999900817871
#                           return [[2. 0.]]
#                     else:  # if A > 1.1349999904632568
#                       return [[3. 0.]]
#                   else:  # if A > 1.1950000524520874
#                     if TightEnds <= 1.5:
#                       if A <= 1.3949999809265137:
#                         return [[ 0. 39.]]
#                       else:  # if A > 1.3949999809265137
#                         if Y <= 32.3700008392334:
#                           if PlayerHeightInches <= 71.5:
#                             if Y <= 27.200000762939453:
#                               if Y <= 25.039999961853027:
#                                 if YardsToTouchdown <= 47.0:
#                                   return [[ 0. 13.]]
#                                 else:  # if YardsToTouchdown > 47.0
#                                   if Age <= 28.5:
#                                     return [[5. 0.]]
#                                   else:  # if Age > 28.5
#                                     return [[0. 6.]]
#                               else:  # if Y > 25.039999961853027
#                                 return [[3. 0.]]
#                             else:  # if Y > 27.200000762939453
#                               return [[ 0. 23.]]
#                           else:  # if PlayerHeightInches > 71.5
#                             return [[ 0. 39.]]
#                         else:  # if Y > 32.3700008392334
#                           return [[2. 0.]]
#                     else:  # if TightEnds > 1.5
#                       return [[ 0. 79.]]
#                 else:  # if Safeties > 2.5
#                   if A <= 1.4950000047683716:
#                     return [[5. 0.]]
#                   else:  # if A > 1.4950000047683716
#                     return [[ 0. 12.]]
#             else:  # if DefendersInTheBox > 7.5
#               if S <= 7.109999895095825:
#                 if Age <= 35.0:
#                   if A <= 1.7899999618530273:
#                     if Y <= 24.714999198913574:
#                       if A <= 1.2649999856948853:
#                         if Y <= 23.43000030517578:
#                           return [[9. 0.]]
#                         else:  # if Y > 23.43000030517578
#                           if Age <= 23.5:
#                             return [[3. 0.]]
#                           else:  # if Age > 23.5
#                             return [[0. 5.]]
#                       else:  # if A > 1.2649999856948853
#                         if PlayerHeightInches <= 72.5:
#                           if Safeties <= 2.5:
#                             if Y <= 22.34999942779541:
#                               if Y <= 21.035000801086426:
#                                 return [[0. 8.]]
#                               else:  # if Y > 21.035000801086426
#                                 if HomeScoreBeforePlay <= 23.5:
#                                   return [[3. 0.]]
#                                 else:  # if HomeScoreBeforePlay > 23.5
#                                   return [[0. 1.]]
#                             else:  # if Y > 22.34999942779541
#                               return [[ 0. 20.]]
#                           else:  # if Safeties > 2.5
#                             return [[2. 0.]]
#                         else:  # if PlayerHeightInches > 72.5
#                           return [[2. 0.]]
#                     else:  # if Y > 24.714999198913574
#                       if TurfCode <= 2.5:
#                         if DefensiveEnds <= 2.5:
#                           if Season <= 2017.5:
#                             if A <= 0.929999977350235:
#                               if IsPossTeamInLead <= 0.5:
#                                 return [[0. 2.]]
#                               else:  # if IsPossTeamInLead > 0.5
#                                 return [[2. 0.]]
#                             else:  # if A > 0.929999977350235
#                               return [[ 0. 39.]]
#                           else:  # if Season > 2017.5
#                             if Y <= 32.41499900817871:
#                               if S <= 4.7149999141693115:
#                                 if OffensiveGuards <= 2.5:
#                                   if A <= 1.5250000357627869:
#                                     return [[7. 0.]]
#                                   else:  # if A > 1.5250000357627869
#                                     if isPlayDirectionLeft <= 0.5:
#                                       return [[0. 3.]]
#                                     else:  # if isPlayDirectionLeft > 0.5
#                                       return [[1. 0.]]
#                                 else:  # if OffensiveGuards > 2.5
#                                   return [[0. 5.]]
#                               else:  # if S > 4.7149999141693115
#                                 if YardsToTouchdown <= 26.5:
#                                   if DefensiveEnds <= 0.5:
#                                     return [[ 0. 10.]]
#                                   else:  # if DefensiveEnds > 0.5
#                                     if TightEnds <= 1.5:
#                                       if HomeScoreBeforePlay <= 10.0:
#                                         return [[0. 8.]]
#                                       else:  # if HomeScoreBeforePlay > 10.0
#                                         return [[2. 0.]]
#                                     else:  # if TightEnds > 1.5
#                                       return [[6. 0.]]
#                                 else:  # if YardsToTouchdown > 26.5
#                                   if A <= 1.5950000286102295:
#                                     return [[ 0. 36.]]
#                                   else:  # if A > 1.5950000286102295
#                                     if DefensiveTackles <= 2.5:
#                                       return [[2. 0.]]
#                                     else:  # if DefensiveTackles > 2.5
#                                       return [[0. 3.]]
#                             else:  # if Y > 32.41499900817871
#                               return [[3. 0.]]
#                         else:  # if DefensiveEnds > 2.5
#                           return [[ 0. 21.]]
#                       else:  # if TurfCode > 2.5
#                         return [[3. 0.]]
#                   else:  # if A > 1.7899999618530273
#                     return [[ 0. 15.]]
#                 else:  # if Age > 35.0
#                   return [[3. 0.]]
#               else:  # if S > 7.109999895095825
#                 return [[4. 0.]]
#           else:  # if Y > 33.77499961853027
#             if DefendersInTheBox <= 6.0:
#               return [[0. 2.]]
#             else:  # if DefendersInTheBox > 6.0
#               return [[7. 0.]]
#       else:  # if A > 1.8550000190734863
#         if YardsToTouchdown <= 2.5:
#           if NoseTackles <= 1.5:
#             if S <= 3.9450000524520874:
#               if Y <= 22.05500030517578:
#                 return [[4. 0.]]
#               else:  # if Y > 22.05500030517578
#                 if Season <= 2017.5:
#                   if StadiumTypeCode <= 1.5:
#                     if A <= 2.0999999046325684:
#                       if Down <= 1.5:
#                         return [[9. 0.]]
#                       else:  # if Down > 1.5
#                         if TurfCode <= 1.5:
#                           return [[0. 9.]]
#                         else:  # if TurfCode > 1.5
#                           return [[1. 0.]]
#                     else:  # if A > 2.0999999046325684
#                       if S <= 3.0799999237060547:
#                         return [[ 0. 23.]]
#                       else:  # if S > 3.0799999237060547
#                         if LineBackers <= 2.5:
#                           return [[ 0. 20.]]
#                         else:  # if LineBackers > 2.5
#                           if A <= 3.0:
#                             if Cornerbacks <= 1.5:
#                               if DefensiveTackles <= 1.5:
#                                 return [[3. 0.]]
#                               else:  # if DefensiveTackles > 1.5
#                                 if OffensiveGuards <= 2.5:
#                                   return [[0. 8.]]
#                                 else:  # if OffensiveGuards > 2.5
#                                   if A <= 2.1149998903274536:
#                                     return [[0. 3.]]
#                                   else:  # if A > 2.1149998903274536
#                                     if NoseTackles <= 0.5:
#                                       return [[3. 0.]]
#                                     else:  # if NoseTackles > 0.5
#                                       return [[0. 1.]]
#                             else:  # if Cornerbacks > 1.5
#                               if DefensiveTackles <= 0.5:
#                                 return [[0. 1.]]
#                               else:  # if DefensiveTackles > 0.5
#                                 return [[8. 0.]]
#                           else:  # if A > 3.0
#                             return [[ 0. 13.]]
#                   else:  # if StadiumTypeCode > 1.5
#                     if HomeScoreBeforePlay <= 16.5:
#                       return [[ 0. 45.]]
#                     else:  # if HomeScoreBeforePlay > 16.5
#                       if A <= 2.4000000953674316:
#                         return [[0. 5.]]
#                       else:  # if A > 2.4000000953674316
#                         return [[2. 0.]]
#                 else:  # if Season > 2017.5
#                   if HomeScoreBeforePlay <= 12.0:
#                     if Y <= 30.994999885559082:
#                       if OffensiveGuards <= 1.5:
#                         return [[6. 0.]]
#                       else:  # if OffensiveGuards > 1.5
#                         if YardsToTouchdown <= 1.5:
#                           if S <= 3.7300000190734863:
#                             if Age <= 24.5:
#                               if OffensiveGuards <= 2.5:
#                                 if S <= 3.3100000619888306:
#                                   return [[0. 8.]]
#                                 else:  # if S > 3.3100000619888306
#                                   if HomeScoreBeforePlay <= 6.5:
#                                     return [[2. 0.]]
#                                   else:  # if HomeScoreBeforePlay > 6.5
#                                     return [[0. 2.]]
#                               else:  # if OffensiveGuards > 2.5
#                                 return [[6. 0.]]
#                             else:  # if Age > 24.5
#                               if PlayerHeightInches <= 72.5:
#                                 return [[ 0. 14.]]
#                               else:  # if PlayerHeightInches > 72.5
#                                 return [[1. 0.]]
#                           else:  # if S > 3.7300000190734863
#                             return [[3. 0.]]
#                         else:  # if YardsToTouchdown > 1.5
#                           if HomeScoreBeforePlay <= 4.5:
#                             return [[11.  0.]]
#                           else:  # if HomeScoreBeforePlay > 4.5
#                             if isPlayDirectionLeft <= 0.5:
#                               return [[3. 0.]]
#                             else:  # if isPlayDirectionLeft > 0.5
#                               return [[0. 6.]]
#                     else:  # if Y > 30.994999885559082
#                       return [[0. 8.]]
#                   else:  # if HomeScoreBeforePlay > 12.0
#                     if PlayerHeightInches <= 69.5:
#                       return [[3. 0.]]
#                     else:  # if PlayerHeightInches > 69.5
#                       if S <= 2.6050000190734863:
#                         return [[2. 0.]]
#                       else:  # if S > 2.6050000190734863
#                         if S <= 3.640000104904175:
#                           if A <= 3.1050000190734863:
#                             return [[ 0. 21.]]
#                           else:  # if A > 3.1050000190734863
#                             if OffensiveGuards <= 1.5:
#                               if PlayerHeightInches <= 70.5:
#                                 if YardsToTouchdown <= 1.5:
#                                   return [[0. 5.]]
#                                 else:  # if YardsToTouchdown > 1.5
#                                   return [[1. 0.]]
#                               else:  # if PlayerHeightInches > 70.5
#                                 return [[ 0. 16.]]
#                             else:  # if OffensiveGuards > 1.5
#                               if LineBackers <= 3.5:
#                                 if Quarter <= 1.5:
#                                   return [[0. 1.]]
#                                 else:  # if Quarter > 1.5
#                                   return [[4. 0.]]
#                               else:  # if LineBackers > 3.5
#                                 return [[0. 6.]]
#                         else:  # if S > 3.640000104904175
#                           if Y <= 28.429999351501465:
#                             if IsPossTeamInLead <= 0.5:
#                               return [[ 0. 11.]]
#                             else:  # if IsPossTeamInLead > 0.5
#                               if DefensiveTackles <= 1.5:
#                                 return [[3. 0.]]
#                               else:  # if DefensiveTackles > 1.5
#                                 return [[0. 4.]]
#                           else:  # if Y > 28.429999351501465
#                             return [[4. 0.]]
#             else:  # if S > 3.9450000524520874
#               if A <= 3.4450000524520874:
#                 if Quarter <= 3.5:
#                   if Y <= 21.239999771118164:
#                     return [[4. 0.]]
#                   else:  # if Y > 21.239999771118164
#                     if PlayerHeightInches <= 71.5:
#                       if StadiumTypeCode <= 1.5:
#                         if Cornerbacks <= 0.5:
#                           if Quarter <= 2.5:
#                             if A <= 2.3499999046325684:
#                               if DefensiveEnds <= 1.5:
#                                 return [[0. 5.]]
#                               else:  # if DefensiveEnds > 1.5
#                                 if DefensiveTackles <= 3.5:
#                                   return [[5. 0.]]
#                                 else:  # if DefensiveTackles > 3.5
#                                   return [[0. 1.]]
#                             else:  # if A > 2.3499999046325684
#                               if Y <= 23.59000015258789:
#                                 return [[1. 0.]]
#                               else:  # if Y > 23.59000015258789
#                                 if A <= 3.1950000524520874:
#                                   return [[ 0. 29.]]
#                                 else:  # if A > 3.1950000524520874
#                                   return [[1. 0.]]
#                           else:  # if Quarter > 2.5
#                             return [[4. 0.]]
#                         else:  # if Cornerbacks > 0.5
#                           if DefendersInTheBox <= 8.5:
#                             if Y <= 22.880000114440918:
#                               return [[3. 0.]]
#                             else:  # if Y > 22.880000114440918
#                               if A <= 3.1100000143051147:
#                                 if Age <= 23.5:
#                                   if DefensiveEnds <= 1.0:
#                                     return [[0. 4.]]
#                                   else:  # if DefensiveEnds > 1.0
#                                     return [[2. 0.]]
#                                 else:  # if Age > 23.5
#                                   return [[ 0. 29.]]
#                               else:  # if A > 3.1100000143051147
#                                 if TimeSnapDiff <= 0.5:
#                                   return [[0. 2.]]
#                                 else:  # if TimeSnapDiff > 0.5
#                                   return [[2. 0.]]
#                           else:  # if DefendersInTheBox > 8.5
#                             if DefensiveEnds <= 0.5:
#                               if PlayerHeightInches <= 70.0:
#                                 return [[0. 4.]]
#                               else:  # if PlayerHeightInches > 70.0
#                                 return [[1. 0.]]
#                             else:  # if DefensiveEnds > 0.5
#                               return [[ 0. 61.]]
#                       else:  # if StadiumTypeCode > 1.5
#                         if DefendersInTheBox <= 7.5:
#                           return [[6. 0.]]
#                         else:  # if DefendersInTheBox > 7.5
#                           if S <= 4.430000066757202:
#                             return [[3. 0.]]
#                           else:  # if S > 4.430000066757202
#                             if Y <= 22.125:
#                               return [[2. 0.]]
#                             else:  # if Y > 22.125
#                               if S <= 5.480000019073486:
#                                 return [[ 0. 14.]]
#                               else:  # if S > 5.480000019073486
#                                 if Down <= 1.5:
#                                   return [[0. 3.]]
#                                 else:  # if Down > 1.5
#                                   return [[2. 0.]]
#                     else:  # if PlayerHeightInches > 71.5
#                       if A <= 2.0649999380111694:
#                         if Y <= 29.219999313354492:
#                           if Age <= 22.5:
#                             return [[1. 0.]]
#                           else:  # if Age > 22.5
#                             return [[ 0. 10.]]
#                         else:  # if Y > 29.219999313354492
#                           return [[4. 0.]]
#                       else:  # if A > 2.0649999380111694
#                         if Centers <= 0.5:
#                           return [[2. 0.]]
#                         else:  # if Centers > 0.5
#                           if A <= 2.6950000524520874:
#                             return [[ 0. 92.]]
#                           else:  # if A > 2.6950000524520874
#                             if Age <= 23.5:
#                               return [[ 0. 40.]]
#                             else:  # if Age > 23.5
#                               if A <= 2.725000023841858:
#                                 return [[2. 0.]]
#                               else:  # if A > 2.725000023841858
#                                 if TightEnds <= 1.5:
#                                   return [[ 0. 37.]]
#                                 else:  # if TightEnds > 1.5
#                                   if isHomeTeam <= 0.5:
#                                     if Age <= 25.0:
#                                       if IsPossTeamInLead <= 0.5:
#                                         return [[2. 0.]]
#                                       else:  # if IsPossTeamInLead > 0.5
#                                         return [[0. 4.]]
#                                     else:  # if Age > 25.0
#                                       return [[2. 0.]]
#                                   else:  # if isHomeTeam > 0.5
#                                     return [[0. 9.]]
#                 else:  # if Quarter > 3.5
#                   if Age <= 24.5:
#                     if DefendersInTheBox <= 9.5:
#                       if Safeties <= 2.5:
#                         if TimeSnapDiff <= 1.5:
#                           if A <= 2.375:
#                             return [[2. 0.]]
#                           else:  # if A > 2.375
#                             if S <= 4.3450000286102295:
#                               if S <= 4.069999933242798:
#                                 return [[0. 3.]]
#                               else:  # if S > 4.069999933242798
#                                 return [[3. 0.]]
#                             else:  # if S > 4.3450000286102295
#                               if HomeScoreBeforePlay <= 25.5:
#                                 return [[ 0. 19.]]
#                               else:  # if HomeScoreBeforePlay > 25.5
#                                 if S <= 4.545000076293945:
#                                   return [[0. 2.]]
#                                 else:  # if S > 4.545000076293945
#                                   return [[2. 0.]]
#                         else:  # if TimeSnapDiff > 1.5
#                           return [[ 0. 14.]]
#                       else:  # if Safeties > 2.5
#                         return [[2. 0.]]
#                     else:  # if DefendersInTheBox > 9.5
#                       return [[ 0. 17.]]
#                   else:  # if Age > 24.5
#                     if Distance <= 1.5:
#                       if HomeScoreBeforePlay <= 27.5:
#                         if A <= 2.274999976158142:
#                           return [[2. 0.]]
#                         else:  # if A > 2.274999976158142
#                           if Cornerbacks <= 2.5:
#                             return [[0. 9.]]
#                           else:  # if Cornerbacks > 2.5
#                             if Season <= 2018.5:
#                               if PlayerHeightInches <= 73.5:
#                                 return [[0. 6.]]
#                               else:  # if PlayerHeightInches > 73.5
#                                 return [[1. 0.]]
#                             else:  # if Season > 2018.5
#                               return [[3. 0.]]
#                       else:  # if HomeScoreBeforePlay > 27.5
#                         return [[5. 0.]]
#                     else:  # if Distance > 1.5
#                       return [[7. 0.]]
#               else:  # if A > 3.4450000524520874
#                 if DefensiveTackles <= 0.5:
#                   if DefensiveEnds <= 1.5:
#                     return [[3. 0.]]
#                   else:  # if DefensiveEnds > 1.5
#                     return [[0. 2.]]
#                 else:  # if DefensiveTackles > 0.5
#                   if S <= 5.640000104904175:
#                     if TimeSnapDiff <= 0.5:
#                       return [[1. 0.]]
#                     else:  # if TimeSnapDiff > 0.5
#                       if Y <= 30.869999885559082:
#                         if S <= 5.0950000286102295:
#                           return [[  0. 121.]]
#                         else:  # if S > 5.0950000286102295
#                           if Y <= 23.0:
#                             return [[1. 0.]]
#                           else:  # if Y > 23.0
#                             return [[ 0. 14.]]
#                       else:  # if Y > 30.869999885559082
#                         if Y <= 31.149999618530273:
#                           return [[1. 0.]]
#                         else:  # if Y > 31.149999618530273
#                           return [[0. 4.]]
#                   else:  # if S > 5.640000104904175
#                     if Y <= 30.84500026702881:
#                       return [[2. 0.]]
#                     else:  # if Y > 30.84500026702881
#                       return [[0. 3.]]
#           else:  # if NoseTackles > 1.5
#             if HomeScoreBeforePlay <= 15.0:
#               if StadiumTypeCode <= 1.5:
#                 if DefensiveEnds <= 1.5:
#                   return [[6. 0.]]
#                 else:  # if DefensiveEnds > 1.5
#                   if Quarter <= 1.5:
#                     return [[3. 0.]]
#                   else:  # if Quarter > 1.5
#                     if Down <= 2.5:
#                       if Safeties <= 1.5:
#                         if DefensiveTackles <= 1.5:
#                           return [[6. 0.]]
#                         else:  # if DefensiveTackles > 1.5
#                           return [[0. 1.]]
#                       else:  # if Safeties > 1.5
#                         if HomeScoreBeforePlay <= 1.5:
#                           return [[0. 6.]]
#                         else:  # if HomeScoreBeforePlay > 1.5
#                           if A <= 2.40500009059906:
#                             return [[2. 0.]]
#                           else:  # if A > 2.40500009059906
#                             if Y <= 30.085000038146973:
#                               return [[0. 8.]]
#                             else:  # if Y > 30.085000038146973
#                               if HomeScoreBeforePlay <= 5.0:
#                                 return [[0. 1.]]
#                               else:  # if HomeScoreBeforePlay > 5.0
#                                 return [[2. 0.]]
#                     else:  # if Down > 2.5
#                       return [[ 0. 10.]]
#               else:  # if StadiumTypeCode > 1.5
#                 return [[ 0. 10.]]
#             else:  # if HomeScoreBeforePlay > 15.0
#               return [[6. 0.]]
#         else:  # if YardsToTouchdown > 2.5
#           if Distance <= 1.5:
#             if Y <= 32.57499885559082:
#               if Season <= 2017.5:
#                 if A <= 1.9350000023841858:
#                   if Y <= 28.03499984741211:
#                     if Safeties <= 1.5:
#                       return [[0. 3.]]
#                     else:  # if Safeties > 1.5
#                       return [[5. 0.]]
#                   else:  # if Y > 28.03499984741211
#                     return [[ 0. 20.]]
#                 else:  # if A > 1.9350000023841858
#                   if A <= 4.420000076293945:
#                     if OffensiveGuards <= 0.5:
#                       return [[1. 0.]]
#                     else:  # if OffensiveGuards > 0.5
#                       if S <= 4.575000047683716:
#                         if S <= 4.325000047683716:
#                           if YardsToTouchdown <= 77.5:
#                             if S <= 4.305000066757202:
#                               if TightEnds <= 0.5:
#                                 if DefensiveTackles <= 1.5:
#                                   return [[0. 4.]]
#                                 else:  # if DefensiveTackles > 1.5
#                                   return [[2. 0.]]
#                               else:  # if TightEnds > 0.5
#                                 if HomeScoreBeforePlay <= 16.5:
#                                   if DefendersInTheBox <= 6.5:
#                                     if S <= 4.055000066757202:
#                                       if Y <= 31.40000057220459:
#                                         if Cornerbacks <= 2.5:
#                                           if IsPossTeamInLead <= 0.5:
#                                             return [[0. 6.]]
#                                           else:  # if IsPossTeamInLead > 0.5
#                                             if Centers <= 0.5:
#                                               return [[0. 1.]]
#                                             else:  # if Centers > 0.5
#                                               return [[2. 0.]]
#                                         else:  # if Cornerbacks > 2.5
#                                           if YardsToTouchdown <= 67.0:
#                                             return [[ 0. 67.]]
#                                           else:  # if YardsToTouchdown > 67.0
#                                             if YardsToTouchdown <= 69.0:
#                                               return [[1. 0.]]
#                                             else:  # if YardsToTouchdown > 69.0
#                                               return [[ 0. 10.]]
#                                       else:  # if Y > 31.40000057220459
#                                         return [[1. 0.]]
#                                     else:  # if S > 4.055000066757202
#                                       if isPlayDirectionLeft <= 0.5:
#                                         return [[0. 1.]]
#                                       else:  # if isPlayDirectionLeft > 0.5
#                                         return [[3. 0.]]
#                                   else:  # if DefendersInTheBox > 6.5
#                                     if A <= 3.7450000047683716:
#                                       if A <= 2.7050000429153442:
#                                         if A <= 2.6950000524520874:
#                                           if OffensiveGuards <= 2.5:
#                                             if S <= 2.409999966621399:
#                                               if Age <= 23.5:
#                                                 return [[1. 0.]]
#                                               else:  # if Age > 23.5
#                                                 return [[ 0. 11.]]
#                                             else:  # if S > 2.409999966621399
#                                               return [[  0. 219.]]
#                                           else:  # if OffensiveGuards > 2.5
#                                             if StadiumTypeCode <= 3.5:
#                                               if YardsToTouchdown <= 20.5:
#                                                 if TimeSnapDiff <= 1.5:
#                                                   return [[1. 0.]]
#                                                 else:  # if TimeSnapDiff > 1.5
#                                                   return [[0. 1.]]
#                                               else:  # if YardsToTouchdown > 20.5
#                                                 return [[ 0. 50.]]
#                                             else:  # if StadiumTypeCode > 3.5
#                                               return [[1. 0.]]
#                                         else:  # if A > 2.6950000524520874
#                                           if isHomeTeam <= 0.5:
#                                             return [[0. 5.]]
#                                           else:  # if isHomeTeam > 0.5
#                                             return [[1. 0.]]
#                                       else:  # if A > 2.7050000429153442
#                                         return [[  0. 188.]]
#                                     else:  # if A > 3.7450000047683716
#                                       if Age <= 26.0:
#                                         return [[2. 0.]]
#                                       else:  # if Age > 26.0
#                                         return [[0. 6.]]
#                                 else:  # if HomeScoreBeforePlay > 16.5
#                                   if Centers <= 1.5:
#                                     if Y <= 30.545000076293945:
#                                       if A <= 1.9900000095367432:
#                                         return [[1. 0.]]
#                                       else:  # if A > 1.9900000095367432
#                                         if isPlayDirectionLeft <= 0.5:
#                                           return [[  0. 100.]]
#                                         else:  # if isPlayDirectionLeft > 0.5
#                                           if S <= 2.7949999570846558:
#                                             if YardsToTouchdown <= 54.0:
#                                               return [[2. 0.]]
#                                             else:  # if YardsToTouchdown > 54.0
#                                               return [[0. 2.]]
#                                           else:  # if S > 2.7949999570846558
#                                             if DefendersInTheBox <= 9.5:
#                                               if Centers <= 0.5:
#                                                 if Down <= 2.5:
#                                                   if S <= 3.600000023841858:
#                                                     return [[2. 0.]]
#                                                   else:  # if S > 3.600000023841858
#                                                     return [[0. 3.]]
#                                                 else:  # if Down > 2.5
#                                                   return [[ 0. 11.]]
#                                               else:  # if Centers > 0.5
#                                                 return [[ 0. 80.]]
#                                             else:  # if DefendersInTheBox > 9.5
#                                               return [[1. 0.]]
#                                     else:  # if Y > 30.545000076293945
#                                       if Y <= 30.860000610351562:
#                                         return [[3. 0.]]
#                                       else:  # if Y > 30.860000610351562
#                                         if Age <= 27.5:
#                                           return [[ 0. 15.]]
#                                         else:  # if Age > 27.5
#                                           return [[1. 0.]]
#                                   else:  # if Centers > 1.5
#                                     if Y <= 23.550000190734863:
#                                       return [[3. 0.]]
#                                     else:  # if Y > 23.550000190734863
#                                       if DefendersInTheBox <= 8.5:
#                                         return [[0. 8.]]
#                                       else:  # if DefendersInTheBox > 8.5
#                                         return [[1. 0.]]
#                             else:  # if S > 4.305000066757202
#                               return [[1. 0.]]
#                           else:  # if YardsToTouchdown > 77.5
#                             if Age <= 28.5:
#                               if TimeSnapDiff <= 1.5:
#                                 return [[ 0. 26.]]
#                               else:  # if TimeSnapDiff > 1.5
#                                 if isPlayDirectionLeft <= 0.5:
#                                   return [[1. 0.]]
#                                 else:  # if isPlayDirectionLeft > 0.5
#                                   return [[0. 2.]]
#                             else:  # if Age > 28.5
#                               if Centers <= 1.5:
#                                 return [[4. 0.]]
#                               else:  # if Centers > 1.5
#                                 return [[0. 1.]]
#                         else:  # if S > 4.325000047683716
#                           return [[ 0. 99.]]
#                       else:  # if S > 4.575000047683716
#                         if DefensiveEnds <= 2.5:
# ...
#                                                 return [[3. 0.]]
#                                             else:  # if S > 5.495000123977661
#                                               return [[0. 5.]]
#                                     else:  # if S > 6.0
#                                       return [[0. 7.]]
#                               else:  # if YardsToTouchdown > 78.5
#                                 if Y <= 30.670000076293945:
#                                   return [[15.  0.]]
#                                 else:  # if Y > 30.670000076293945
#                                   if IsPossTeamInLead <= 0.5:
#                                     return [[2. 0.]]
#                                   else:  # if IsPossTeamInLead > 0.5
#                                     return [[0. 1.]]
#                   else:  # if Y > 31.550000190734863
#                     if Distance <= 7.5:
#                       if S <= 5.114999771118164:
#                         return [[0. 6.]]
#                       else:  # if S > 5.114999771118164
#                         return [[2. 0.]]
#                     else:  # if Distance > 7.5
#                       if TightEnds <= 0.5:
#                         return [[0. 1.]]
#                       else:  # if TightEnds > 0.5
#                         return [[51.  0.]]
#                 else:  # if A > 3.584999918937683
#                   if Y <= 32.079999923706055:
#                     if A <= 3.8249999284744263:
#                       if DefensiveEnds <= 2.5:
#                         if S <= 5.444999933242798:
#                           if YardsToTouchdown <= 63.5:
#                             if IsPossTeamInLead <= 0.5:
#                               if isHomeTeam <= 0.5:
#                                 return [[7. 0.]]
#                               else:  # if isHomeTeam > 0.5
#                                 if DefendersInTheBox <= 5.5:
#                                   return [[2. 0.]]
#                                 else:  # if DefendersInTheBox > 5.5
#                                   if YardsToTouchdown <= 28.0:
#                                     if TurfCode <= 1.5:
#                                       return [[0. 4.]]
#                                     else:  # if TurfCode > 1.5
#                                       if HomeScoreBeforePlay <= 27.5:
#                                         return [[4. 0.]]
#                                       else:  # if HomeScoreBeforePlay > 27.5
#                                         return [[0. 1.]]
#                                   else:  # if YardsToTouchdown > 28.0
#                                     return [[ 0. 10.]]
#                             else:  # if IsPossTeamInLead > 0.5
#                               return [[18.  0.]]
#                           else:  # if YardsToTouchdown > 63.5
#                             if Quarter <= 1.5:
#                               if NoseTackles <= 0.5:
#                                 if Distance <= 8.5:
#                                   if PlayerHeightInches <= 72.0:
#                                     return [[2. 0.]]
#                                   else:  # if PlayerHeightInches > 72.0
#                                     return [[0. 4.]]
#                                 else:  # if Distance > 8.5
#                                   return [[ 0. 28.]]
#                               else:  # if NoseTackles > 0.5
#                                 return [[2. 0.]]
#                             else:  # if Quarter > 1.5
#                               if Cornerbacks <= 2.5:
#                                 if Y <= 28.869999885559082:
#                                   return [[13.  0.]]
#                                 else:  # if Y > 28.869999885559082
#                                   if A <= 3.7050000429153442:
#                                     return [[0. 4.]]
#                                   else:  # if A > 3.7050000429153442
#                                     return [[3. 0.]]
#                               else:  # if Cornerbacks > 2.5
#                                 if HomeScoreBeforePlay <= 20.0:
#                                   if S <= 4.6499998569488525:
#                                     return [[0. 5.]]
#                                   else:  # if S > 4.6499998569488525
#                                     if Age <= 21.5:
#                                       return [[0. 1.]]
#                                     else:  # if Age > 21.5
#                                       if YardsToTouchdown <= 68.0:
#                                         if A <= 3.7200000286102295:
#                                           return [[1. 0.]]
#                                         else:  # if A > 3.7200000286102295
#                                           return [[0. 1.]]
#                                       else:  # if YardsToTouchdown > 68.0
#                                         return [[7. 0.]]
#                                 else:  # if HomeScoreBeforePlay > 20.0
#                                   return [[ 0. 12.]]
#                         else:  # if S > 5.444999933242798
#                           return [[13.  0.]]
#                       else:  # if DefensiveEnds > 2.5
#                         if TightEnds <= 1.5:
#                           return [[ 0. 20.]]
#                         else:  # if TightEnds > 1.5
#                           if Cornerbacks <= 2.5:
#                             return [[3. 0.]]
#                           else:  # if Cornerbacks > 2.5
#                             return [[0. 2.]]
#                     else:  # if A > 3.8249999284744263
#                       if Y <= 30.1850004196167:
#                         if DefensiveEnds <= 2.5:
#                           if YardsToTouchdown <= 74.5:
#                             if A <= 5.605000019073486:
#                               if HomeScoreBeforePlay <= 27.5:
#                                 if A <= 3.90500009059906:
#                                   return [[10.  0.]]
#                                 else:  # if A > 3.90500009059906
#                                   if S <= 5.634999990463257:
#                                     if DefendersInTheBox <= 6.5:
#                                       if DefendersInTheBox <= 5.5:
#                                         return [[3. 0.]]
#                                       else:  # if DefendersInTheBox > 5.5
#                                         if Age <= 30.5:
#                                           if TightEnds <= 1.5:
#                                             if StadiumTypeCode <= 3.0:
#                                               if S <= 5.2149999141693115:
#                                                 return [[ 0. 36.]]
#                                               else:  # if S > 5.2149999141693115
#                                                 if S <= 5.295000076293945:
#                                                   return [[1. 0.]]
#                                                 else:  # if S > 5.295000076293945
#                                                   return [[0. 4.]]
#                                             else:  # if StadiumTypeCode > 3.0
#                                               return [[1. 0.]]
#                                           else:  # if TightEnds > 1.5
#                                             return [[2. 0.]]
#                                         else:  # if Age > 30.5
#                                           if YardsToTouchdown <= 65.5:
#                                             return [[4. 0.]]
#                                           else:  # if YardsToTouchdown > 65.5
#                                             return [[0. 2.]]
#                                     else:  # if DefendersInTheBox > 6.5
#                                       if PlayerHeightInches <= 71.5:
#                                         if PlayerHeightInches <= 68.5:
#                                           return [[4. 0.]]
#                                         else:  # if PlayerHeightInches > 68.5
#                                           if Age <= 28.5:
#                                             if DefensiveTackles <= 0.5:
#                                               return [[2. 0.]]
#                                             else:  # if DefensiveTackles > 0.5
#                                               if TurfCode <= 2.5:
#                                                 if Quarter <= 3.5:
#                                                   if A <= 4.819999933242798:
#                                                     if Distance <= 8.5:
#                                                       if Distance <= 7.5:
#                                                         return [[0. 3.]]
#                                                       else:  # if Distance > 7.5
#                                                         return [[1. 0.]]
#                                                     else:  # if Distance > 8.5
#                                                       return [[ 0. 21.]]
#                                                   else:  # if A > 4.819999933242798
#                                                     return [[1. 0.]]
#                                                 else:  # if Quarter > 3.5
#                                                   if DefendersInTheBox <= 8.5:
#                                                     return [[2. 0.]]
#                                                   else:  # if DefendersInTheBox > 8.5
#                                                     return [[0. 1.]]
#                                               else:  # if TurfCode > 2.5
#                                                 return [[2. 0.]]
#                                           else:  # if Age > 28.5
#                                             return [[2. 0.]]
#                                       else:  # if PlayerHeightInches > 71.5
#                                         if S <= 5.059999942779541:
#                                           return [[17.  0.]]
#                                         else:  # if S > 5.059999942779541
#                                           if Season <= 2018.5:
#                                             return [[0. 3.]]
#                                           else:  # if Season > 2018.5
#                                             return [[1. 0.]]
#                                   else:  # if S > 5.634999990463257
#                                     return [[7. 0.]]
#                               else:  # if HomeScoreBeforePlay > 27.5
#                                 if YardsToTouchdown <= 14.5:
#                                   return [[1. 0.]]
#                                 else:  # if YardsToTouchdown > 14.5
#                                   return [[ 0. 18.]]
#                             else:  # if A > 5.605000019073486
#                               return [[12.  0.]]
#                           else:  # if YardsToTouchdown > 74.5
#                             if S <= 5.534999847412109:
#                               if Y <= 28.494999885559082:
#                                 if A <= 3.834999918937683:
#                                   if StadiumTypeCode <= 1.5:
#                                     return [[1. 0.]]
#                                   else:  # if StadiumTypeCode > 1.5
#                                     return [[0. 1.]]
#                                 else:  # if A > 3.834999918937683
#                                   return [[38.  0.]]
#                               else:  # if Y > 28.494999885559082
#                                 if NoseTackles <= 0.5:
#                                   if Centers <= 0.5:
#                                     return [[1. 0.]]
#                                   else:  # if Centers > 0.5
#                                     return [[0. 8.]]
#                                 else:  # if NoseTackles > 0.5
#                                   return [[3. 0.]]
#                             else:  # if S > 5.534999847412109
#                               if Quarter <= 2.5:
#                                 return [[5. 0.]]
#                               else:  # if Quarter > 2.5
#                                 if YardsToTouchdown <= 93.5:
#                                   return [[ 0. 14.]]
#                                 else:  # if YardsToTouchdown > 93.5
#                                   return [[1. 0.]]
#                         else:  # if DefensiveEnds > 2.5
#                           if PlayerHeightInches <= 72.5:
#                             return [[19.  0.]]
#                           else:  # if PlayerHeightInches > 72.5
#                             if YardsToTouchdown <= 42.5:
#                               return [[0. 4.]]
#                             else:  # if YardsToTouchdown > 42.5
#                               return [[4. 0.]]
#                       else:  # if Y > 30.1850004196167
#                         if Age <= 27.5:
#                           return [[27.  0.]]
#                         else:  # if Age > 27.5
#                           if DefensiveEnds <= 1.5:
#                             return [[3. 0.]]
#                           else:  # if DefensiveEnds > 1.5
#                             return [[0. 4.]]
#                   else:  # if Y > 32.079999923706055
#                     if PlayerHeightInches <= 70.5:
#                       return [[3. 0.]]
#                     else:  # if PlayerHeightInches > 70.5
#                       if S <= 4.7149999141693115:
#                         return [[2. 0.]]
#                       else:  # if S > 4.7149999141693115
#                         return [[ 0. 23.]]
#               else:  # if Y > 32.795000076293945
#                 return [[23.  0.]]
#         else:  # if Distance > 11.5
#           if DefensiveTackles <= 2.5:
#             if isPlayDirectionLeft <= 0.5:
#               if A <= 4.575000047683716:
#                 return [[100.   0.]]
#               else:  # if A > 4.575000047683716
#                 if TimeSnapDiff <= 1.5:
#                   return [[7. 0.]]
#                 else:  # if TimeSnapDiff > 1.5
#                   if isHomeTeam <= 0.5:
#                     return [[1. 0.]]
#                   else:  # if isHomeTeam > 0.5
#                     return [[0. 2.]]
#             else:  # if isPlayDirectionLeft > 0.5
#               if YardsToTouchdown <= 68.5:
#                 if YardsToTouchdown <= 33.5:
#                   return [[23.  0.]]
#                 else:  # if YardsToTouchdown > 33.5
#                   if YardsToTouchdown <= 35.5:
#                     return [[0. 5.]]
#                   else:  # if YardsToTouchdown > 35.5
#                     if Y <= 24.229999542236328:
#                       if HomeScoreBeforePlay <= 12.0:
#                         if YardsToTouchdown <= 59.5:
#                           if Quarter <= 2.5:
#                             return [[4. 0.]]
#                           else:  # if Quarter > 2.5
#                             if Safeties <= 1.5:
#                               return [[1. 0.]]
#                             else:  # if Safeties > 1.5
#                               return [[0. 5.]]
#                         else:  # if YardsToTouchdown > 59.5
#                           return [[0. 6.]]
#                       else:  # if HomeScoreBeforePlay > 12.0
#                         return [[4. 0.]]
#                     else:  # if Y > 24.229999542236328
#                       if Age <= 21.5:
#                         if DefensiveEnds <= 1.5:
#                           return [[1. 0.]]
#                         else:  # if DefensiveEnds > 1.5
#                           return [[0. 1.]]
#                       else:  # if Age > 21.5
#                         return [[22.  0.]]
#               else:  # if YardsToTouchdown > 68.5
#                 return [[53.  0.]]
#           else:  # if DefensiveTackles > 2.5
#             if TimeSnapDiff <= 1.5:
#               return [[5. 0.]]
#             else:  # if TimeSnapDiff > 1.5
#               if Y <= 26.019999504089355:
#                 return [[1. 0.]]
#               else:  # if Y > 26.019999504089355
#                 return [[0. 8.]]

# %%
# The score method returns the accuracy of the model
score = dtree.score(X_test, y_test)
print(score)
# Out:
# 0.8798816568047337

# %%
# List of values to try for max_depth:
max_depth_range = list(range(1, numDimensions + 1))# List to store the average RMSE for each value of max_depth:
accuracy = []
for depth in max_depth_range:
    
    clf = DecisionTreeClassifier(max_depth = depth, random_state = 0)
    clf.fit(X_train, y_train)    
    score = clf.score(X_test, y_test)
    accuracy.append(score)
    
pd.DataFrame(accuracy)
# Out:
#            0
# 0   0.721746
# 1   0.721746
# 2   0.723669
# 3   0.730695
# 4   0.734246
# 5   0.738462
# 6   0.741642
# 7   0.747411
# 8   0.751997
# 9   0.761391
# 10  0.772485
# 11  0.784246
# 12  0.791050
# 13  0.803846
# 14  0.812500
# 15  0.821006
# 16  0.830030
# 17  0.840089
# 18  0.850074
# 19  0.854882
# 20  0.860503
# 21  0.867456
# 22  0.868121
# 23  0.871154
# 24  0.875222
# 25  0.878328
# 26  0.878994

# %%
importances = pd.DataFrame({'feature':X_train.columns,'importance':np.round(clf.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False)
importances.head(5)
# Out:
#              feature  importance
# 21          Distance       0.247
# 10                 A       0.108
# 23                 S       0.105
# 9                  Y       0.087
# 26  YardsToTouchdown       0.071
