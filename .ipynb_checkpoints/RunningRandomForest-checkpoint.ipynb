# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import classification_report,confusion_matrix #import Confusion Matrix

from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot 
import time

# %%
df = pd.read_csv("bank_marketing/bank_cleaned.csv",index_col=0)

# %%
featrueCols=list(['balance','duration', 'campaign','agerangen','jobn','maritaln','educationn','contactn','defaultn','housingn','loann','monthn'])
#featrueCols=list(['balance','campaign','agerangen','jobn','maritaln','educationn','defaultn','housingn','loann'])
#featrueCols

# %%
#df['pdays']=df['pdays'].fillna(-1)
#df[featrueCols]

# %%
#split dataset in features and target variable
X = df[featrueCols] # Features
y = df['y'] # Target variable

# %%
# Split the data to Training and test, using the stratifying method
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, 
                                                    random_state=int(time.time()), stratify=y)

# %%
# Create Decision Tree classifer object
rfc = RandomForestClassifier(n_estimators=10,criterion="entropy", max_depth=4)

# %%
# Train Decision Tree Classifer
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Predict the response for test dataset
predictions = rfc.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.8817204301075269

# %%
#Present Confusion Matrix to show accuracy
print(classification_report(y_test,predictions),'\n',confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.88      1.00      0.94      1149
#          yes       0.33      0.01      0.01       153
#
#     accuracy                           0.88      1302
#    macro avg       0.61      0.50      0.47      1302
# weighted avg       0.82      0.88      0.83      1302
#
#  [[1147    2]
#  [ 152    1]]

# %%
features = list(featrueCols)
#features

# %%
dot_data = StringIO()  
export_graphviz(rfc.estimators_[0], out_file=dot_data,feature_names=features,filled=True,rounded=True,rotate=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png(), width=7860, height=2160)
